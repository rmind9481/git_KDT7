# %% [markdown]
# [ Matplotlib의 상자수염그래프(Boxplot / Box Whisker plot)]
#
# - 데이터의 분포 체크위한 시각화 그래프
# - 이상치/패턴 파악 가능함

# %% [markdown]
# [1] 모듈로딩 <hr>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# [2] 데이타 준비 <hr>

# %%
## 파일 준비

D_FILE = '../DATA/auto_mpg.csv'

autoDF = pd.read_csv(D_FILE)
autoDF.head()


plt.boxplot(autoDF['mpg'], label='mpg')
plt.legend()
plt.show()

# %%
plt.boxplot(autoDF['mpg'], label='mpg',
            notch=True, vert=False)
plt.legend()
plt.show()

# %%
# 기본 박스 플롯

data_name = ['mpg','cylinders','acceleration']

boxplot = plt.boxplot(autoDF[data_name], 
                      labels=data_name,
                      notch=True)
plt.legend()
plt.show()
# Out:
# C:\Users\KDT17\AppData\Local\Temp\ipykernel_14288\1376210058.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   boxplot = plt.boxplot(autoDF[data_name],
# C:\Users\KDT17\AppData\Local\Temp\ipykernel_14288\1376210058.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print(f'boxplot 객체 포함 정보\n{boxplot.keys()}')

for key in boxplot.keys():
    print(f'[{key}]====\n{boxplot[key]}\n')
# Out:
# boxplot 객체 포함 정보
# dict_keys(['whiskers', 'caps', 'boxes', 'medians', 'fliers', 'means'])
# [whiskers]====
# [<matplotlib.lines.Line2D object at 0x00000283E6DE8580>, <matplotlib.lines.Line2D object at 0x00000283E6DE84F0>, <matplotlib.lines.Line2D object at 0x00000283E6DD6DC0>, <matplotlib.lines.Line2D object at 0x00000283E6E0A0A0>, <matplotlib.lines.Line2D object at 0x00000283E6DFB0A0>, <matplotlib.lines.Line2D object at 0x00000283E6DFB340>]
#
# [caps]====
# [<matplotlib.lines.Line2D object at 0x00000283E6DD60A0>, <matplotlib.lines.Line2D object at 0x00000283E6DD6340>, <matplotlib.lines.Line2D object at 0x00000283E6E0A340>, <matplotlib.lines.Line2D object at 0x00000283E6E0A5E0>, <matplotlib.lines.Line2D object at 0x00000283E6DFB5E0>, <matplotlib.lines.Line2D object at 0x00000283E6DFB880>]
#
# [boxes]====
# [<matplotlib.lines.Line2D object at 0x00000283E6DE8D30>, <matplotlib.lines.Line2D object at 0x00000283E6DD6B20>, <matplotlib.lines.Line2D object at 0x00000283E6E0ADC0>]
#
# [medians]====
# [<matplotlib.lines.Line2D object at 0x00000283E6DD65E0>, <matplotlib.lines.Line2D object at 0x00000283E6E0A880>, <matplotlib.lines.Line2D object at 0x00000283E6DFBB20>]
#
# [fliers]====
# [<matplotlib.lines.Line2D object at 0x00000283E6DD6880>, <matplotlib.lines.Line2D object at 0x00000283E6E0AB20>, <matplotlib.lines.Line2D object at 0x00000283E6DFBDC0>]
#
# [means]====
# []

# %%
print(f'boxplot["whiskers"] : {len(boxplot["whiskers"])}개')
for w in boxplot["whiskers"]:
    print(w.get_ydata())
# Out:
# boxplot["whiskers"] : 6개
# [17.5  9. ]
# [29.  44.6]
# [4. 3.]
# [8. 8.]
# [13.825  9.   ]
# [17.175 22.2  ]

# %%
print(f'boxplot["fliers"] : {len(boxplot["fliers"])}개')
for m in boxplot["fliers"]:
    print(m.get_ydata())
# Out:
# boxplot["fliers"] : 3개
# [46.6]
# []
# [ 8.5  8.5  8.  23.5 24.8 23.7 24.6]
