# %%
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

# %%
query = 'ChatGPT'
url = f'https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query={query}'


# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')

html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')
blog_results = soup.select('a.title_link')
desc_results = soup.select('a.dsc_link')
search_count = len(blog_results)
print('검색 결과: ', search_count)

for i in range(search_count):
	title = blog_results[i].text
	link = blog_results[i]['href']
	print(f'{title},[{link}]')
	print(desc_results[i].text)
	print('-'*80)
# Out:
# 검색 결과:  30
# ChatGPT 3.5 무료, 4.0 유료 팁 정리,[https://blog.naver.com/yjg01212/223753299753]
# ChatGPT 3.5 4.0, 무료 유료 팁 정리 안녕하세요, IT 블로거 아이보리입니다. OpenAI의 대화형 인공지능 서비스, 챗GPT가 출시한지도 어느덧 2년이란 시간이 넘었습니다. 그동안에 정말 많은 변화를 거쳤고, 지금은 우리 일상에서도 많은 영향을 끼치는 그런 AI라 해도 과언이 아닌 수준이죠. 오늘은 ChatGPT 3.5 (무료) 및 4.0 (유료)에 관한 개념 정리와 팁 위주로...
# --------------------------------------------------------------------------------
# 챗gpt 무료 vs 유료 차이 ChatGPT 4.0 합리적인 사용법 찾았다!,[https://blog.naver.com/aimei96/223757591755]
# 챗gpt 무료 유료 차이 ChatGPT 4.0 사용법 안녕하세요! 메이입니다. 요새 정말 AI의 발전 속도가 어마어마한데요. 처음 나왔을 때는 아쉬운 부분이 많았는데 이제는 어떻게 쓰느냐에... 한 달만 쓴다고 한다면 써볼 수도 있겠지만, 아마 ChatGPT 사용법을 찾으시는 대부분의 유저분들은 이미 프리 버전을 써보신 후 유료로 넘어가고자 찾아보시는 분들이 대부분일...
# --------------------------------------------------------------------------------
# CHATGPT 4.0 유료 / 3.5 무료 차이는?,[https://blog.naver.com/okok1326/223752689220]
# 다른 분들도 그러시겠지만, 개인적으로 요새 CHATGPT 사용 빈도가 크게 늘었는데요. 특히 챗지피티 유료 버전을 사용하면서 굉장히 큰 만족감을 느끼고 있습니다. 아직 챗지피티 무료 버전을 사용하고 계신 분들이 많을 텐데, 이번 포스팅으로 CHATGPT 4.0 유료와 3.5 무료에 어떤 차이가 있는지 / 또 어떻게 하면 조금 더 합리적인 가격에 이용할 수 있을지...
# --------------------------------------------------------------------------------
# chatgpt 가격 챗GPT 할인 프로모션 코드 사용법,[https://blog.naver.com/babohyunjoo/223761680185]
# chatgpt 가격 챗GPT 할인 프로모션 코드 사용법 1. chatgpt 가격 챗GPT 할인 프로모션 코드 테크 업계를 주도하는 AI 기술의 리더, ChatGPT가 놀라운 진화를 이루고 있습니다. 레거시 무료 버전과는 차원이 다른 퍼포먼스를 보여주고 있네요. DALL-E 기반 이미지 제너레이션과 실시간 데이터 프로세싱이 가능해졌고, 네이티브 스피커급 자연어 처리 능력으로 마치...
# --------------------------------------------------------------------------------
# 챗지피티 유료와 무료 차이점! ChatGPT 4.0 가격 겜스고 할인 코드 이용하기,[https://blog.naver.com/jjang986/223666205446]
# AI가 일상이 된 요즘, 챗지피티(ChatGPT)는 빠르게 우리의 삶 속에 녹아들고 있습니다. 누구나 쉽게 접근할 수 있는 챗GPT 무료 버전부터 강력한 성능을 자랑하는 유료 버전까지, 각각의 장점과 특징은 명확합니다. 오늘은 챗지피티 유료와 무료의 차이점을 명확히 짚어보고, 특히 ChatGPT 4.0을 저렴하게 사용할 수 있는 겜스고(GamsGo)와 할인 코드 정보도 함께 알아볼게요....
# --------------------------------------------------------------------------------
# 중국 AI 딥시크 Deepseek chatGPT 4.0 비교,[https://blog.naver.com/obama8775/223739793848]
# 이번 포스팅에서는 DeepSeek과 OpenAI의 ChatGPT 4.0을 비교하며 각 모델의 장단점과 향후 전망을 분석해보겠습니다. 딥시크(DeepSeek)와 ChatGPT 4.0의 개요 DeepSeek는 중국의 AI 기업이 개발한 자연어 처리(NLP) 기반의 인공지능 모델입니다. 기존 서구권 AI 모델 대비 상대적으로 저렴한 GPU 환경에서도 높은 성능을 발휘할 수 있도록 최적화되었습니다. 특히...
# --------------------------------------------------------------------------------
# ChatGPT vs Claude, 수능 성적 결과는?,[https://post.naver.com/viewer/postView.naver?volumeNo=40967116&memberNo=6457418&vType=VERTICAL]
# “ChatGPT 美 변호사 시험 상위 10%로 통과”“Claude 3, AI 첫 IQ 100 돌파”  위와 같이 AI의 능력을 홍보하는 문구들을 자주 접하셨을 것 같습니다. 이러한 성과들이 대단해 보이기는 하지만, 한편으로는 그 수준이 어느 정도인지 체감이 안될 때가 있는데요. 마침 지난 목요일 치러진 2025 대학 수능 시험을 통해 AI 능력을 시험해 보기로 했습니다. 우선...
# --------------------------------------------------------------------------------
# SKT 챗GPT chatGPT PLUS 50% 할인 이벤트 신청방법 알아보기,[https://blog.naver.com/daumsky22/223759674686]
# 이번 SKT 사용자라면 챗GPT ChatGPT Plus를 3개월간 50% 할인된 금액으로 이용할 수 있는데요, 해당 이벤트를 신청하는 방법과 사용하는 방법까지 자세하게 알아보겠습니다. 프로모션 개요 SKT가 오픈 AI와 손잡고 국내 최초로 진행하는 이 할인 행사는 챗GPT ChatGPT의 프리미엄 서비스인 ChatGPT Plus를 3개월 동안 반값에 이용할 수 있게 해줍니다. 이는 작년...
# --------------------------------------------------------------------------------
# chatgpt 4.0 사용법 챗지피티 무료 유료 차이 챗gpt 4o 가격 chat gpt 4 할인 그림 공유,[https://blog.naver.com/cayque/223701524762]
# 오늘은 요즘 많은 관심을 받고 있는 OpenAI의 인공지능 chatgpt 사용법과 근래에 업데이트 출시된 chatgpt 4o의 차이 그리고 chatgpt 4.0 싸게 할인받는법에 대해 살펴보겠다. chatgpt 3.5 Free 플랜 버전은 몇 년 전의 정보를 제공하고 텍스트만 지원하는데다 어휘력도 부족하기 때문에 현재는 무료이다. chatgpt 4.0 즉 GPT Plus는 최신의 정보 및 빠른 응답속도 그리고...
# --------------------------------------------------------------------------------
# [마카오여행]일반정보-경제, 사회, 정치, 복지(f. ChatGpt),[https://blog.naver.com/monghill/223736633756]
# 그래서 ChatGpt를 통해 알아봤다. 마카오는 어느 정도나 먹고 사는지? 1. 마카오의 경제 수준 GDP : 약 470억 달러(1999년 대비 약 7배 성장) 1인당 GDP : 약 69,000달러 (한화 1억원)... 국가 금액 (단위 : 달러) 마카오 69,000 홍콩 49,000 싱가포르 72,000 한국 37,000 chatgpt가 마카오에 딱 어울리는 이미지를 찾았다 3. 마카오 주요 산업 카지노 산업이 전체 GDP의 약 50% 이상을...
# --------------------------------------------------------------------------------
# 챗지피티(ChatGPT)로 저렴하게 동영상 뽑는 법,[https://blog.naver.com/13_11_16a/223700574361]
# 그래서 ChatGPT에게 동영상을 만들어달라고 부탁해도, 만들어주지 않습니다. 그러면 이제 유료로 결제를 해야하는데, 결제 금액을 보면 금액이 작은 것도 아니고, SORA AI만 결제할... ChatGPT에게 그림을 그려달라고 요청할 수 있는 '크레딧'이 매일 제한되어 있어서, 인원수가 적으면 적을수록 내가 쓸 파이가 늘어난다고 보시면 됩니다. 저도 챗GPT 잠깐 썼을때...
# --------------------------------------------------------------------------------
# 워프애드5기 - 워드프레스 수익화 클래스 5기 모집안내 (ChatGPT + 애드센스),[https://blog.naver.com/resumet/223763536345]
# 워프애드5기 - 워드프레스 수익화 클래스 5기 모집안내 (ChatGPT + 애드센스) 경제 사정이 팍팍해지고 있습니다. 소득은 줄고 있고, 월급은 제자리입니다. 대안으로 선택한 네이버... 초기 ChatGPT 의 결과물을 보고 너무 실망했기 때문입니다. 게다가 검색시장에 인공지능으로 만든 쓰레기 같은 글들이 범람하는 것을 보고 부정적인 생각은 더욱 커졌습니다. 그러나, ChatGPT...
# --------------------------------------------------------------------------------
# ChatGPT 플러스 할인 완벽 이용 가이드,[https://blog.naver.com/mok0724/223758543275]
# 오늘은 제가 실제로 ChatGPT 플러스를 사용하면서 알게 된 할인 꿀팁을 이웃님들과 공유하려고 합니다. 자주 ChatGPT를 사용하다 보니 무료 버전의 한계를 많이 느끼고 플러스 요금제를 좀 더 저렴하게 이용할 수 있는 방법을 찾아보다가 알게 된 방법을 정리해 보았습니다. ChatGPT 무료 버전과 플러스 버전 비교 ChatGPT 무료 버전은 기본적인 채팅이나 음성...
# --------------------------------------------------------------------------------
# 24년 미국 주식시장 정리하는 차트 10가지 / Perplexity vs. ChatGPT 프롬프트 대결! / 기대치를 밑도는 중국 제조업 PMI,[https://blog.naver.com/thefirstrain/223710951720]
# 자투리 소식 투자에 도움이 되는 소식, 재미 #중국제조업PMI #천연가스선물 #Perplexity #ChatGPT #생성형AI 12월 중국 제조업 PMI(=공장 가동률?)가 예상보다 낮았다. 예상 50.3, 11월도 50.3.... Perplexity와 ChatGPT에 다양한 유형의 프롬프트를 주고 성능을 비교했다. 주관적인 평가이지만 생각하던 것과 비슷한 결과가 나왔다. & 최근 퍼플렉시티보다 ChatGPT의 사용빈도가 훨씬...
# --------------------------------------------------------------------------------
# 챗 GPT 모델 종류 소개 ChatGPT 저렴하게 이용하는 방법은?,[https://blog.naver.com/cchkill/223759876810]
# 그중 ChatGPT는 OpenAI에서 개발한 대규모 언어 모델(Large Language Model)을 기반으로 한 대화형 AI 챗봇입니다. 오늘은 ChatGPT의 종류와 저렴하게 이용할 수 있는 방법에 대해서 알아보겠습니다. ChatGPT 모델의 종류는? ChatGPT는 크게 GPT-3.5계열, GPT-4 계열로 나누어집니다. 최근에는 여러 서드파티 플랫폼을 통해서 다양한 하위 버전, 커스텀 모델들이 나왔죠....
# --------------------------------------------------------------------------------
# 중국 AI, 'ChatGPT보다 50배 더 우수' 주식시장에서 1조 달러 손실,[https://blog.naver.com/seenewskr/223740831808]
# ChatGPT와 같은 챗봇에 대항하는 저렴한 중국 경쟁 업체자가 출시되면서 기술계는 충격을 받았으며 주가는 폭락했다. DeepSeek은 이번 달 초에 출시되었으며 현재 영국과 미국의 Apple 앱 스토어에서 가장 인기 있는 무료 앱으로 자리매김했다. Gemini와 ChatGPT 와 같은 유명 AI 모델은 독점적인 반면, DeepSeek은 '오픈 소스'로 누구나 코드를 보고 이를 기반으로 개발을...
# --------------------------------------------------------------------------------
# ChatGPT 4.0 vs 챗GPT 3.5 핵심 비교 분석,[https://blog.naver.com/reviewermax/223761270496]
# 마무리 이제는 ChatGPT를 한 번쯤 사용해보지 않은 분이 있을까 싶다. 그만큼 ChatGPT는 이제 널리 알려져 있다. 다만 발전을 거듭하며 여러가지 버전이 출시되면서 다소 혼란스럽긴하다. 무료로 사용할 수 있는 ChatGPT 3.5까지는 상당히 인지도가 있다. 반면 4.0 혹은 4o 버전을 내놓으면서 유료로 바뀌기 시작했고, 이제부터는 뭐가 어떻게 다른건지조차 이해하기가...
# --------------------------------------------------------------------------------
# ChatGPT 무료 유료 차이점, 쳇GPT 4o 가격 저렴하게 이용하기,[https://blog.naver.com/cyg0703nani/223733001841]
# 얼마 전 ChatGPT 무료 버전에서 구형 모델 3.5 버전이 아닌 ChatGPT 4o mini 상위 언어 모델을 제한적으로 이용할 수 있게 되었고, 유료 버전에서는 복잡한 코딩과 수학적 추론, 브레인스토밍, 비교 분석에 특화된 o1 버전을 이용할 수 있게 되었는데요. 이번 시간에는 ChatGPT 무료와 유료의 차이점을 알아보고, 유료 버전인 쳇 GPT 4o를 저렴하게 이용하는 법을 자세히...
# --------------------------------------------------------------------------------
# ChatGPT는 원달러환율을 얼마로 예상할까?,[https://blog.naver.com/phpboy/223706767910]
# ChatGPT는 원달러환율을 얼마로 예상할까? ChatGPT 챗지피티에게 원달러 환율이 얼마나 오를지 물어보았다. ChatGPT는 환율이 영향을 미치는 주요요인들을 다음과 같이 보여주었다. 사실상 누구나 알만한 내용이다. 미국의 금리 정책: 미국 연방준비제도(Fed)의 금리 인상이나 인하가 원달러 환율에 큰 영향을 미친다. 미국 금리가 높으면 달러 강세가 나타나고, 이는 원화...
# --------------------------------------------------------------------------------
# 중국의 AI 딥시크 R1 ChatGPT를 넘어설 수 있을까?! 기능 및 특징 비교,[https://blog.naver.com/flythfk2/223740607979]
# 그래서 오늘은 딥시크 R1의 특장점과 ChatGPT 등 기존 AI 모델과 어떤 차별점을 가지고 있는지 자세히 알아보도록 하겠습니다. 딥시크 AI, 누구냐 너? 딥시크는 중국의 환팡퀀트... ChatGPT와 딥시크 R1, 뭐가 다를까? 그렇다면 ChatGPT와 딥시크 R1의 차이점은 뭘까요?가장 큰 차이는 비용 효율성과 학습 방식에 있습니다. ChatGPT는 막대한 자원을 투입해 모델을...
# --------------------------------------------------------------------------------
# ChatGPT 놀이 ~~,[https://blog.naver.com/nohappy0/223699531521]
# 요새 ChatGPT 로 놀이를 하고 있다. 막 인터넷이 나왔을 때 누군가와 채팅을 하는 재미, 네이버 지식인의 질문을 하고 대답을 하는 재미, 블로그를 통해 남의 생활과 생각을 보는 재미, 유튜브를 보는 재미 이런것들에 이어서 하는 취미 생활이다. 어제 공정성 관련된 글을 썼고, 그 글을 모두 ChatGPT에게 송부를 하고 검토를 부탁했다. 아래는 질문이다. "아래는 공정성...
# --------------------------------------------------------------------------------
# ChatGPT에게 핵심 질문은 어떻게 할까요?,[https://blog.naver.com/bls1105/223752475112]
# ChatGPT에게 핵심 질문은 어떻게 할까요? 출처 : ChatGPT 말 챗 GPT에게 핵심적인 질문을 하는 방법은 다음과 같습니다. 1. 명확하고 구체적으로 질문하기 ✅ 좋은 예: "노인들이 쉽게 배울 수 있는 인터넷 활용 강의 주제 5가지 추천해 주세요." "다낭에서 중산층이 선호하는 거주 지역과 특징을 알려주세요." ❌ 좋지 않은 예: "인터넷 강의 뭐가 좋아?" → (범위가...
# --------------------------------------------------------------------------------
# 윈도우11 에서 ChatGPT 앱을 사용하면 더 좋습니다.,[https://hkebi.tistory.com/3097]
# 이제 정말 많은 분들이 ChatGPT 나 코파일럿 같은 AI 를 굉장히 많이 활용을 하고 있습니다. ChatGPT 의 경우 이제 윈도우용 앱도 제공을 하고 있습니다. 그냥 웹에서 사용을 해도 큰 문제는 없지만 앱을 사용을 하면 조금더 좋은점들이 있습니다. 이번 글에서는 윈도우11 에서 ChatGPT 를 앱을 설치해서 사용을 하게 되면 좋은 점들에 대해서 알아 보도록 하겠습니다. ChatGPT...
# --------------------------------------------------------------------------------
# 쳇GPT 무료 장단점 사용법 유료 챗지피티 4.0 4o 공유 chatgpt gtp,[https://blog.naver.com/toresi/223662575202]
# 그래서 오늘은 효율적인 소비를 위해 chatgpt 무료만큼 저렴하게 챗gtp 유료 서비스를 이용할 수 있는 비법을 알려드리겠습니다. chatgpt 4.0을 저렴하게 구입하는 비결은 바로 겜스고에서 제공하는 지피티챗 할인코드 사용에 있습니다! ️✨ chatgtp를 할인받기 위해 번거롭게 신용카드를 새로 만들거나, 통신사 멤버십에 가입할 필요 없이 간단하게 할인을 받을 수...
# --------------------------------------------------------------------------------
# 챗지피티(ChatGPT) 사주 AI로 보는 나의 운세 어떻게?,[https://blog.naver.com/gusdltjgml/223761599929]
# 챗지피티(ChatGPT) 사주 AI로 보는 나의 운세 어떻게? 사주, 이제 AI에게 물어보자! 사주는 예전부터 많은 사람이 궁금해하는 분야 중 하나다. 과거에는 철학관이나 전문가를 찾아가야만 볼 수 있었지만, 이제는 챗지피티(ChatGPT) 같은 AI를 활용해 간편하게 사주를 볼 수 있다. 신기해서 직접 시도해봤는데, 생각보다 꽤 그럴듯한 결과가 나와 흥미로웠다. AI가 사주를...
# --------------------------------------------------------------------------------
# 챗GPT 유료 무료 차이 ChatGPT 4.0 할인코드 챗지피티 블로그,[https://blog.naver.com/parangsae71/223735586089]
# 챗GPT 유료 무료 차이 ChatGPT 4.0 할인코드 챗지피티 블로그 네이버 경제인플루언서 강팰입니다. 경제 블로그는 챗GPT를 이용한 글쓰기가 어느새 필수가 되었습니다. 1월달에는... 챗GPT 유료플랜 저렴하기 이용하기 ChatGPT4.0은 일반 버전보다 5배 빠른 응답 속도와 향상된 메시지 처리 능력, AI 음성 대화 기능 등으로 작업 효율을 크게 높여주는 뛰어난 성능을...
# --------------------------------------------------------------------------------
# [ChatGPT] ChatGPT 사용법 알아보기,[https://blog.naver.com/niar_/223711539406]
# 도구: ChatGPT 무료: 무료 가능 URL: https://chatgpt.com/ 2025.1.3: 최초 작성 ChatGPT는 OpenAI에서 개발한 인공지능 언어 모델입니다. 다양한 언어를 이해하고 생성할 수 있으며, 대화형 응답을 통해 질문에 답하거나, 텍스트를 생성하거나, 사용자에게 유용한 정보를 제공할 수 있습니다. 또한, 다양한 주제에 대해 학습을 통해 대화가 자연스럽고 사람처럼 느껴지도록...
# --------------------------------------------------------------------------------
# Open AI ChatGPT 윈도우 PC 버전 설치 및 챗GPT 음성 채팅 사용법,[https://blog.naver.com/feena74/223681556774]
# ChatGPT Plus 사용자에게만 제공되던 ChatGPT 윈도우 PC 버전이 이제 무료 사용자도 사용할 수 있게 되었습니다. 더불어, 그동안 지원하지 않던 PC 버전의 음성 채팅 기능도 새롭게 추가되어, 이제는 스마트폰을 사용하지 않고도 윈도우 컴퓨터에서 작업하면서 음성 채팅을 손쉽게 이용할 수 있게 되었는데요. 이번 포스팅에서는 윈도우 버전 설치 방법과 함께, 챗GPT PC...
# --------------------------------------------------------------------------------
# CHATgpt 에게 물어본 현금 3억원 투자 방법,[https://blog.naver.com/climbmylife/223741558487]
# 설연휴에 심심해서 핸드폰을 가지고 놀다가 지금 당장 현금 3억원을 어떻게 투자하면 좋을지를 CHATgpt에 물어봤습니다. 챗지피티가 쭉 내용을 설명한 뒤에 다음과 같은 결론을 내놨습니다. 결론: 포트폴리오 구성 제안 3억원을 효과적으로 배분하는 방법을 제안하면 다음과 같습니다. 정기예금: 1억원 (안정적인 자산 유지) 부동산: 1.5억원 (임대 수익 및...
# --------------------------------------------------------------------------------
# ChatGPT(챗GPT) Taks(작업) 기능 사용 및 AI Agency 시대에 대해,[https://blog.naver.com/richrule/223730702807]
# 좌측 상단에서 chatgpt 작업을 선택해도 동일하며, 메시지 입력에 작업을 정리한다. 간단하게 강의 관련 컨텐츠에 대한 최신 내용 정리를 요청했다. 앞으로 이렇게 보내주겠다는?... 내용을 deppl로 번역 후 붙여넣기 및 저장 입력한 시간이 되면 chatgpt 가입 이메일로 알림을 받는다. 기사는 잘 정리했으나 블로그 포스팅 제목은 오지 않았다. 아직 베타버전이라 오류가...
# --------------------------------------------------------------------------------
