# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# 현재 실습하고 있는 파이썬 코드를 재실행해도
# 다음에도 같은 결과가 나오도록 랜덤 시드(random seed) 설정
torch.manual_seed(1)

# %%
# 데이터 준비 --------------------------------------------------
x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

# %%
print(f'x_train : {x_train.shape}, {x_train.ndim} \n{x_train}')
print(f'y_train : {y_train.shape}, {y_train.ndim} \n{y_train}')
# Out:
# x_train : torch.Size([3, 1]), 2
# tensor([[1.],
#         [2.],
#         [3.]])
# y_train : torch.Size([3, 1]), 2
# tensor([[2.],
#         [4.],
#         [6.]])

# %%
# Model 초기화 -------------------------------------------------
# 가중치 W 0으로 초기화하고 학습 통해 값이 변경되는 변수 명시함
# requires_grad=True  <= 학습을 통해 계속 값이 변경되는 변수임 의미
# y= Wx+b = 0x + 0
# torch.zeros(텐서 원소 갯수)
W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

print(f'W : {W}, b : {b}')
# Out:
# W : tensor([0.], requires_grad=True), b : tensor([0.], requires_grad=True)

# %%
# 경사하강법 => W,b 업데이트
# W,b 변수, 학습률지정
optimizer = optim.SGD([W, b], lr=0.01)

# %%
# 학습 --------------------------------------------------------
nb_epochs = 1999 # 원하는만큼 경사 하강법을 반복

for epoch in range(nb_epochs + 1):

    # H(x) 계산 = XW+b => 예측값
    hypothesis = x_train * W + b

    # cost 계산 = (예측값 - 정답)
    cost = torch.mean((hypothesis - y_train) ** 2)

    # cost로 H(x) 개선
    optimizer.zero_grad()      # gradient를 0으로 초기화
    cost.backward()            # 비용 함수를 미분하여 gradient 계산
    print('수식을 w로 미분한 값 : {}'.format(W.grad))

    optimizer.step()           # W, b 업데이트
    print(f'업데이트 된 W : {W.grad}, b : {b.grad}')


    # 100번마다 로그 출력
    if epoch % 100 == 0:
        print(f'Epoch {epoch:4d}/{nb_epochs} W: { W.item():.3f}, b: {b.item():.3f} Cost: {cost.item():.6f}')
# Out:
# 수식을 w로 미분한 값 : tensor([-18.6667])
# 업데이트 된 W : tensor([-18.6667]), b : tensor([-8.])
# Epoch    0/1999 W: 0.187, b: 0.080 Cost: 18.666666
# 수식을 w로 미분한 값 : tensor([-16.6044])
# 업데이트 된 W : tensor([-16.6044]), b : tensor([-7.0933])
# 수식을 w로 미분한 값 : tensor([-14.7710])
# 업데이트 된 W : tensor([-14.7710]), b : tensor([-6.2873])
# 수식을 w로 미분한 값 : tensor([-13.1408])
# 업데이트 된 W : tensor([-13.1408]), b : tensor([-5.5707])
# 수식을 w로 미분한 값 : tensor([-11.6915])
# 업데이트 된 W : tensor([-11.6915]), b : tensor([-4.9337])
# 수식을 w로 미분한 값 : tensor([-10.4030])
# 업데이트 된 W : tensor([-10.4030]), b : tensor([-4.3673])
# 수식을 w로 미분한 값 : tensor([-9.2573])
# 업데이트 된 W : tensor([-9.2573]), b : tensor([-3.8639])
# 수식을 w로 미분한 값 : tensor([-8.2388])
# 업데이트 된 W : tensor([-8.2388]), b : tensor([-3.4163])
# 수식을 w로 미분한 값 : tensor([-7.3332])
# 업데이트 된 W : tensor([-7.3332]), b : tensor([-3.0184])
# 수식을 w로 미분한 값 : tensor([-6.5280])
# 업데이트 된 W : tensor([-6.5280]), b : tensor([-2.6647])
# 수식을 w로 미분한 값 : tensor([-5.8121])
# 업데이트 된 W : tensor([-5.8121]), b : tensor([-2.3503])
# 수식을 w로 미분한 값 : tensor([-5.1757])
# 업데이트 된 W : tensor([-5.1757]), b : tensor([-2.0708])
# 수식을 w로 미분한 값 : tensor([-4.6098])
# 업데이트 된 W : tensor([-4.6098]), b : tensor([-1.8224])
# 수식을 w로 미분한 값 : tensor([-4.1066])
# 업데이트 된 W : tensor([-4.1066]), b : tensor([-1.6015])
# 수식을 w로 미분한 값 : tensor([-3.6593])
# 업데이트 된 W : tensor([-3.6593]), b : tensor([-1.4052])
# 수식을 w로 미분한 값 : tensor([-3.2615])
# 업데이트 된 W : tensor([-3.2615]), b : tensor([-1.2308])
# 수식을 w로 미분한 값 : tensor([-2.9079])
# 업데이트 된 W : tensor([-2.9079]), b : tensor([-1.0757])
# 수식을 w로 미분한 값 : tensor([-2.5935])
# 업데이트 된 W : tensor([-2.5935]), b : tensor([-0.9379])
# 수식을 w로 미분한 값 : tensor([-2.3139])
# 업데이트 된 W : tensor([-2.3139]), b : tensor([-0.8154])
# 수식을 w로 미분한 값 : tensor([-2.0653])
# 업데이트 된 W : tensor([-2.0653]), b : tensor([-0.7065])
# 수식을 w로 미분한 값 : tensor([-1.8443])
# 업데이트 된 W : tensor([-1.8443]), b : tensor([-0.6097])
# 수식을 w로 미분한 값 : tensor([-1.6478])
# 업데이트 된 W : tensor([-1.6478]), b : tensor([-0.5238])
# 수식을 w로 미분한 값 : tensor([-1.4730])
# 업데이트 된 W : tensor([-1.4730]), b : tensor([-0.4474])
# 수식을 w로 미분한 값 : tensor([-1.3176])
# 업데이트 된 W : tensor([-1.3176]), b : tensor([-0.3795])
# 수식을 w로 미분한 값 : tensor([-1.1795])
# 업데이트 된 W : tensor([-1.1795]), b : tensor([-0.3192])
# 수식을 w로 미분한 값 : tensor([-1.0566])
# 업데이트 된 W : tensor([-1.0566]), b : tensor([-0.2657])
# 수식을 w로 미분한 값 : tensor([-0.9474])
# 업데이트 된 W : tensor([-0.9474]), b : tensor([-0.2181])
# 수식을 w로 미분한 값 : tensor([-0.8502])
# 업데이트 된 W : tensor([-0.8502]), b : tensor([-0.1758])
# 수식을 w로 미분한 값 : tensor([-0.7639])
# 업데이트 된 W : tensor([-0.7639]), b : tensor([-0.1383])
# 수식을 w로 미분한 값 : tensor([-0.6870])
# 업데이트 된 W : tensor([-0.6870]), b : tensor([-0.1050])
# 수식을 w로 미분한 값 : tensor([-0.6187])
# 업데이트 된 W : tensor([-0.6187]), b : tensor([-0.0754])
# 수식을 w로 미분한 값 : tensor([-0.5579])
# 업데이트 된 W : tensor([-0.5579]), b : tensor([-0.0491])
# 수식을 w로 미분한 값 : tensor([-0.5039])
# 업데이트 된 W : tensor([-0.5039]), b : tensor([-0.0258])
# 수식을 w로 미분한 값 : tensor([-0.4558])
# 업데이트 된 W : tensor([-0.4558]), b : tensor([-0.0052])
# 수식을 w로 미분한 값 : tensor([-0.4131])
# 업데이트 된 W : tensor([-0.4131]), b : tensor([0.0132])
# 수식을 w로 미분한 값 : tensor([-0.3751])
# 업데이트 된 W : tensor([-0.3751]), b : tensor([0.0294])
# 수식을 w로 미분한 값 : tensor([-0.3412])
# 업데이트 된 W : tensor([-0.3412]), b : tensor([0.0438])
# 수식을 w로 미분한 값 : tensor([-0.3111])
# 업데이트 된 W : tensor([-0.3111]), b : tensor([0.0566])
# 수식을 w로 미분한 값 : tensor([-0.2844])
# 업데이트 된 W : tensor([-0.2844]), b : tensor([0.0679])
# 수식을 w로 미분한 값 : tensor([-0.2605])
# 업데이트 된 W : tensor([-0.2605]), b : tensor([0.0779])
# 수식을 w로 미분한 값 : tensor([-0.2393])
# 업데이트 된 W : tensor([-0.2393]), b : tensor([0.0868])
# 수식을 w로 미분한 값 : tensor([-0.2205])
# 업데이트 된 W : tensor([-0.2205]), b : tensor([0.0946])
# 수식을 w로 미분한 값 : tensor([-0.2037])
# 업데이트 된 W : tensor([-0.2037]), b : tensor([0.1016])
# 수식을 w로 미분한 값 : tensor([-0.1887])
# 업데이트 된 W : tensor([-0.1887]), b : tensor([0.1077])
# 수식을 w로 미분한 값 : tensor([-0.1754])
# 업데이트 된 W : tensor([-0.1754]), b : tensor([0.1131])
# 수식을 w로 미분한 값 : tensor([-0.1636])
# 업데이트 된 W : tensor([-0.1636]), b : tensor([0.1178])
# 수식을 w로 미분한 값 : tensor([-0.1530])
# 업데이트 된 W : tensor([-0.1530]), b : tensor([0.1220])
# 수식을 w로 미분한 값 : tensor([-0.1436])
# 업데이트 된 W : tensor([-0.1436]), b : tensor([0.1257])
# 수식을 w로 미분한 값 : tensor([-0.1352])
# 업데이트 된 W : tensor([-0.1352]), b : tensor([0.1289])
# 수식을 w로 미분한 값 : tensor([-0.1278])
# 업데이트 된 W : tensor([-0.1278]), b : tensor([0.1318])
# 수식을 w로 미분한 값 : tensor([-0.1211])
# 업데이트 된 W : tensor([-0.1211]), b : tensor([0.1342])
# 수식을 w로 미분한 값 : tensor([-0.1152])
# 업데이트 된 W : tensor([-0.1152]), b : tensor([0.1364])
# 수식을 w로 미분한 값 : tensor([-0.1099])
# 업데이트 된 W : tensor([-0.1099]), b : tensor([0.1383])
# 수식을 w로 미분한 값 : tensor([-0.1052])
# 업데이트 된 W : tensor([-0.1052]), b : tensor([0.1399])
# 수식을 w로 미분한 값 : tensor([-0.1009])
# 업데이트 된 W : tensor([-0.1009]), b : tensor([0.1413])
# 수식을 w로 미분한 값 : tensor([-0.0972])
# 업데이트 된 W : tensor([-0.0972]), b : tensor([0.1425])
# 수식을 w로 미분한 값 : tensor([-0.0938])
# 업데이트 된 W : tensor([-0.0938]), b : tensor([0.1436])
# 수식을 w로 미분한 값 : tensor([-0.0908])
# 업데이트 된 W : tensor([-0.0908]), b : tensor([0.1444])
# 수식을 w로 미분한 값 : tensor([-0.0881])
# 업데이트 된 W : tensor([-0.0881]), b : tensor([0.1452])
# 수식을 w로 미분한 값 : tensor([-0.0857])
# 업데이트 된 W : tensor([-0.0857]), b : tensor([0.1458])
# 수식을 w로 미분한 값 : tensor([-0.0835])
# 업데이트 된 W : tensor([-0.0835]), b : tensor([0.1463])
# 수식을 w로 미분한 값 : tensor([-0.0816])
# 업데이트 된 W : tensor([-0.0816]), b : tensor([0.1467])
# 수식을 w로 미분한 값 : tensor([-0.0798])
# 업데이트 된 W : tensor([-0.0798]), b : tensor([0.1471])
# 수식을 w로 미분한 값 : tensor([-0.0783])
# 업데이트 된 W : tensor([-0.0783]), b : tensor([0.1473])
# 수식을 w로 미분한 값 : tensor([-0.0769])
# 업데이트 된 W : tensor([-0.0769]), b : tensor([0.1475])
# 수식을 w로 미분한 값 : tensor([-0.0756])
# 업데이트 된 W : tensor([-0.0756]), b : tensor([0.1476])
# 수식을 w로 미분한 값 : tensor([-0.0744])
# 업데이트 된 W : tensor([-0.0744]), b : tensor([0.1477])
# 수식을 w로 미분한 값 : tensor([-0.0734])
# 업데이트 된 W : tensor([-0.0734]), b : tensor([0.1477])
# 수식을 w로 미분한 값 : tensor([-0.0725])
# 업데이트 된 W : tensor([-0.0725]), b : tensor([0.1477])
# 수식을 w로 미분한 값 : tensor([-0.0716])
# 업데이트 된 W : tensor([-0.0716]), b : tensor([0.1476])
# 수식을 w로 미분한 값 : tensor([-0.0708])
# 업데이트 된 W : tensor([-0.0708]), b : tensor([0.1476])
# 수식을 w로 미분한 값 : tensor([-0.0701])
# 업데이트 된 W : tensor([-0.0701]), b : tensor([0.1474])
# 수식을 w로 미분한 값 : tensor([-0.0695])
# 업데이트 된 W : tensor([-0.0695]), b : tensor([0.1473])
# 수식을 w로 미분한 값 : tensor([-0.0689])
# 업데이트 된 W : tensor([-0.0689]), b : tensor([0.1471])
# 수식을 w로 미분한 값 : tensor([-0.0683])
# 업데이트 된 W : tensor([-0.0683]), b : tensor([0.1469])
# 수식을 w로 미분한 값 : tensor([-0.0678])
# 업데이트 된 W : tensor([-0.0678]), b : tensor([0.1467])
# 수식을 w로 미분한 값 : tensor([-0.0674])
# 업데이트 된 W : tensor([-0.0674]), b : tensor([0.1465])
# 수식을 w로 미분한 값 : tensor([-0.0669])
# 업데이트 된 W : tensor([-0.0669]), b : tensor([0.1463])
# 수식을 w로 미분한 값 : tensor([-0.0665])
# 업데이트 된 W : tensor([-0.0665]), b : tensor([0.1460])
# 수식을 w로 미분한 값 : tensor([-0.0662])
# 업데이트 된 W : tensor([-0.0662]), b : tensor([0.1458])
# 수식을 w로 미분한 값 : tensor([-0.0658])
# 업데이트 된 W : tensor([-0.0658]), b : tensor([0.1455])
# 수식을 w로 미분한 값 : tensor([-0.0655])
# 업데이트 된 W : tensor([-0.0655]), b : tensor([0.1452])
# 수식을 w로 미분한 값 : tensor([-0.0652])
# 업데이트 된 W : tensor([-0.0652]), b : tensor([0.1449])
# 수식을 w로 미분한 값 : tensor([-0.0649])
# 업데이트 된 W : tensor([-0.0649]), b : tensor([0.1446])
# 수식을 w로 미분한 값 : tensor([-0.0646])
# 업데이트 된 W : tensor([-0.0646]), b : tensor([0.1443])
# 수식을 w로 미분한 값 : tensor([-0.0644])
# 업데이트 된 W : tensor([-0.0644]), b : tensor([0.1440])
# 수식을 w로 미분한 값 : tensor([-0.0641])
# 업데이트 된 W : tensor([-0.0641]), b : tensor([0.1437])
# 수식을 w로 미분한 값 : tensor([-0.0639])
# 업데이트 된 W : tensor([-0.0639]), b : tensor([0.1434])
# 수식을 w로 미분한 값 : tensor([-0.0637])
# 업데이트 된 W : tensor([-0.0637]), b : tensor([0.1431])
# 수식을 w로 미분한 값 : tensor([-0.0635])
# 업데이트 된 W : tensor([-0.0635]), b : tensor([0.1428])
# 수식을 w로 미분한 값 : tensor([-0.0632])
# 업데이트 된 W : tensor([-0.0632]), b : tensor([0.1425])
# 수식을 w로 미분한 값 : tensor([-0.0630])
# 업데이트 된 W : tensor([-0.0630]), b : tensor([0.1422])
# 수식을 w로 미분한 값 : tensor([-0.0628])
# 업데이트 된 W : tensor([-0.0628]), b : tensor([0.1418])
# 수식을 w로 미분한 값 : tensor([-0.0627])
# 업데이트 된 W : tensor([-0.0627]), b : tensor([0.1415])
# 수식을 w로 미분한 값 : tensor([-0.0625])
# 업데이트 된 W : tensor([-0.0625]), b : tensor([0.1412])
# 수식을 w로 미분한 값 : tensor([-0.0623])
# 업데이트 된 W : tensor([-0.0623]), b : tensor([0.1409])
# 수식을 w로 미분한 값 : tensor([-0.0621])
# 업데이트 된 W : tensor([-0.0621]), b : tensor([0.1405])
# 수식을 w로 미분한 값 : tensor([-0.0619])
# 업데이트 된 W : tensor([-0.0619]), b : tensor([0.1402])
# 수식을 w로 미분한 값 : tensor([-0.0618])
# 업데이트 된 W : tensor([-0.0618]), b : tensor([0.1399])
# 수식을 w로 미분한 값 : tensor([-0.0616])
# 업데이트 된 W : tensor([-0.0616]), b : tensor([0.1396])
# 수식을 w로 미분한 값 : tensor([-0.0614])
# 업데이트 된 W : tensor([-0.0614]), b : tensor([0.1392])
# Epoch  100/1999 W: 1.746, b: 0.578 Cost: 0.048171
# 수식을 w로 미분한 값 : tensor([-0.0613])
# 업데이트 된 W : tensor([-0.0613]), b : tensor([0.1389])
# 수식을 w로 미분한 값 : tensor([-0.0611])
# 업데이트 된 W : tensor([-0.0611]), b : tensor([0.1386])
# 수식을 w로 미분한 값 : tensor([-0.0609])
# 업데이트 된 W : tensor([-0.0609]), b : tensor([0.1383])
# 수식을 w로 미분한 값 : tensor([-0.0608])
# 업데이트 된 W : tensor([-0.0608]), b : tensor([0.1379])
# 수식을 w로 미분한 값 : tensor([-0.0606])
# 업데이트 된 W : tensor([-0.0606]), b : tensor([0.1376])
# 수식을 w로 미분한 값 : tensor([-0.0605])
# 업데이트 된 W : tensor([-0.0605]), b : tensor([0.1373])
# 수식을 w로 미분한 값 : tensor([-0.0603])
# 업데이트 된 W : tensor([-0.0603]), b : tensor([0.1369])
# 수식을 w로 미분한 값 : tensor([-0.0602])
# 업데이트 된 W : tensor([-0.0602]), b : tensor([0.1366])
# 수식을 w로 미분한 값 : tensor([-0.0600])
# 업데이트 된 W : tensor([-0.0600]), b : tensor([0.1363])
# 수식을 w로 미분한 값 : tensor([-0.0599])
# 업데이트 된 W : tensor([-0.0599]), b : tensor([0.1360])
# 수식을 w로 미분한 값 : tensor([-0.0597])
# 업데이트 된 W : tensor([-0.0597]), b : tensor([0.1356])
# 수식을 w로 미분한 값 : tensor([-0.0596])
# 업데이트 된 W : tensor([-0.0596]), b : tensor([0.1353])
# 수식을 w로 미분한 값 : tensor([-0.0594])
# 업데이트 된 W : tensor([-0.0594]), b : tensor([0.1350])
# 수식을 w로 미분한 값 : tensor([-0.0593])
# 업데이트 된 W : tensor([-0.0593]), b : tensor([0.1347])
# 수식을 w로 미분한 값 : tensor([-0.0591])
# 업데이트 된 W : tensor([-0.0591]), b : tensor([0.1344])
# 수식을 w로 미분한 값 : tensor([-0.0590])
# 업데이트 된 W : tensor([-0.0590]), b : tensor([0.1340])
# 수식을 w로 미분한 값 : tensor([-0.0588])
# 업데이트 된 W : tensor([-0.0588]), b : tensor([0.1337])
# 수식을 w로 미분한 값 : tensor([-0.0587])
# 업데이트 된 W : tensor([-0.0587]), b : tensor([0.1334])
# 수식을 w로 미분한 값 : tensor([-0.0586])
# 업데이트 된 W : tensor([-0.0586]), b : tensor([0.1331])
# 수식을 w로 미분한 값 : tensor([-0.0584])
# 업데이트 된 W : tensor([-0.0584]), b : tensor([0.1327])
# 수식을 w로 미분한 값 : tensor([-0.0583])
# 업데이트 된 W : tensor([-0.0583]), b : tensor([0.1324])
# 수식을 w로 미분한 값 : tensor([-0.0581])
# 업데이트 된 W : tensor([-0.0581]), b : tensor([0.1321])
# 수식을 w로 미분한 값 : tensor([-0.0580])
# 업데이트 된 W : tensor([-0.0580]), b : tensor([0.1318])
# 수식을 w로 미분한 값 : tensor([-0.0578])
# 업데이트 된 W : tensor([-0.0578]), b : tensor([0.1315])
# 수식을 w로 미분한 값 : tensor([-0.0577])
# 업데이트 된 W : tensor([-0.0577]), b : tensor([0.1312])
# 수식을 w로 미분한 값 : tensor([-0.0576])
# 업데이트 된 W : tensor([-0.0576]), b : tensor([0.1308])
# 수식을 w로 미분한 값 : tensor([-0.0574])
# 업데이트 된 W : tensor([-0.0574]), b : tensor([0.1305])
# 수식을 w로 미분한 값 : tensor([-0.0573])
# 업데이트 된 W : tensor([-0.0573]), b : tensor([0.1302])
# 수식을 w로 미분한 값 : tensor([-0.0572])
# 업데이트 된 W : tensor([-0.0572]), b : tensor([0.1299])
# 수식을 w로 미분한 값 : tensor([-0.0570])
# 업데이트 된 W : tensor([-0.0570]), b : tensor([0.1296])
# 수식을 w로 미분한 값 : tensor([-0.0569])
# 업데이트 된 W : tensor([-0.0569]), b : tensor([0.1293])
# 수식을 w로 미분한 값 : tensor([-0.0567])
# 업데이트 된 W : tensor([-0.0567]), b : tensor([0.1290])
# 수식을 w로 미분한 값 : tensor([-0.0566])
# 업데이트 된 W : tensor([-0.0566]), b : tensor([0.1287])
# 수식을 w로 미분한 값 : tensor([-0.0565])
# 업데이트 된 W : tensor([-0.0565]), b : tensor([0.1284])
# 수식을 w로 미분한 값 : tensor([-0.0563])
# 업데이트 된 W : tensor([-0.0563]), b : tensor([0.1280])
# 수식을 w로 미분한 값 : tensor([-0.0562])
# 업데이트 된 W : tensor([-0.0562]), b : tensor([0.1277])
# 수식을 w로 미분한 값 : tensor([-0.0561])
# 업데이트 된 W : tensor([-0.0561]), b : tensor([0.1274])
# 수식을 w로 미분한 값 : tensor([-0.0559])
# 업데이트 된 W : tensor([-0.0559]), b : tensor([0.1271])
# 수식을 w로 미분한 값 : tensor([-0.0558])
# 업데이트 된 W : tensor([-0.0558]), b : tensor([0.1268])
# 수식을 w로 미분한 값 : tensor([-0.0557])
# 업데이트 된 W : tensor([-0.0557]), b : tensor([0.1265])
# 수식을 w로 미분한 값 : tensor([-0.0555])
# 업데이트 된 W : tensor([-0.0555]), b : tensor([0.1262])
# 수식을 w로 미분한 값 : tensor([-0.0554])
# 업데이트 된 W : tensor([-0.0554]), b : tensor([0.1259])
# 수식을 w로 미분한 값 : tensor([-0.0553])
# 업데이트 된 W : tensor([-0.0553]), b : tensor([0.1256])
# 수식을 w로 미분한 값 : tensor([-0.0551])
# 업데이트 된 W : tensor([-0.0551]), b : tensor([0.1253])
# 수식을 w로 미분한 값 : tensor([-0.0550])
# 업데이트 된 W : tensor([-0.0550]), b : tensor([0.1250])
# 수식을 w로 미분한 값 : tensor([-0.0549])
# 업데이트 된 W : tensor([-0.0549]), b : tensor([0.1247])
# 수식을 w로 미분한 값 : tensor([-0.0547])
# 업데이트 된 W : tensor([-0.0547]), b : tensor([0.1244])
# 수식을 w로 미분한 값 : tensor([-0.0546])
# 업데이트 된 W : tensor([-0.0546]), b : tensor([0.1241])
# 수식을 w로 미분한 값 : tensor([-0.0545])
# 업데이트 된 W : tensor([-0.0545]), b : tensor([0.1238])
# 수식을 w로 미분한 값 : tensor([-0.0543])
# 업데이트 된 W : tensor([-0.0543]), b : tensor([0.1235])
# 수식을 w로 미분한 값 : tensor([-0.0542])
# 업데이트 된 W : tensor([-0.0542]), b : tensor([0.1232])
# 수식을 w로 미분한 값 : tensor([-0.0541])
# 업데이트 된 W : tensor([-0.0541]), b : tensor([0.1229])
# 수식을 w로 미분한 값 : tensor([-0.0539])
# 업데이트 된 W : tensor([-0.0539]), b : tensor([0.1226])
# 수식을 w로 미분한 값 : tensor([-0.0538])
# 업데이트 된 W : tensor([-0.0538]), b : tensor([0.1223])
# 수식을 w로 미분한 값 : tensor([-0.0537])
# 업데이트 된 W : tensor([-0.0537]), b : tensor([0.1220])
# 수식을 w로 미분한 값 : tensor([-0.0536])
# 업데이트 된 W : tensor([-0.0536]), b : tensor([0.1217])
# 수식을 w로 미분한 값 : tensor([-0.0534])
# 업데이트 된 W : tensor([-0.0534]), b : tensor([0.1214])
# 수식을 w로 미분한 값 : tensor([-0.0533])
# 업데이트 된 W : tensor([-0.0533]), b : tensor([0.1212])
# 수식을 w로 미분한 값 : tensor([-0.0532])
# 업데이트 된 W : tensor([-0.0532]), b : tensor([0.1209])
# 수식을 w로 미분한 값 : tensor([-0.0530])
# 업데이트 된 W : tensor([-0.0530]), b : tensor([0.1206])
# 수식을 w로 미분한 값 : tensor([-0.0529])
# 업데이트 된 W : tensor([-0.0529]), b : tensor([0.1203])
# 수식을 w로 미분한 값 : tensor([-0.0528])
# 업데이트 된 W : tensor([-0.0528]), b : tensor([0.1200])
# 수식을 w로 미분한 값 : tensor([-0.0527])
# 업데이트 된 W : tensor([-0.0527]), b : tensor([0.1197])
# 수식을 w로 미분한 값 : tensor([-0.0525])
# 업데이트 된 W : tensor([-0.0525]), b : tensor([0.1194])
# 수식을 w로 미분한 값 : tensor([-0.0524])
# 업데이트 된 W : tensor([-0.0524]), b : tensor([0.1191])
# 수식을 w로 미분한 값 : tensor([-0.0523])
# 업데이트 된 W : tensor([-0.0523]), b : tensor([0.1188])
# 수식을 w로 미분한 값 : tensor([-0.0522])
# 업데이트 된 W : tensor([-0.0522]), b : tensor([0.1186])
# 수식을 w로 미분한 값 : tensor([-0.0520])
# 업데이트 된 W : tensor([-0.0520]), b : tensor([0.1183])
# 수식을 w로 미분한 값 : tensor([-0.0519])
# 업데이트 된 W : tensor([-0.0519]), b : tensor([0.1180])
# 수식을 w로 미분한 값 : tensor([-0.0518])
# 업데이트 된 W : tensor([-0.0518]), b : tensor([0.1177])
# 수식을 w로 미분한 값 : tensor([-0.0517])
# 업데이트 된 W : tensor([-0.0517]), b : tensor([0.1174])
# 수식을 w로 미분한 값 : tensor([-0.0515])
# 업데이트 된 W : tensor([-0.0515]), b : tensor([0.1171])
# 수식을 w로 미분한 값 : tensor([-0.0514])
# 업데이트 된 W : tensor([-0.0514]), b : tensor([0.1169])
# 수식을 w로 미분한 값 : tensor([-0.0513])
# 업데이트 된 W : tensor([-0.0513]), b : tensor([0.1166])
# 수식을 w로 미분한 값 : tensor([-0.0512])
# 업데이트 된 W : tensor([-0.0512]), b : tensor([0.1163])
# 수식을 w로 미분한 값 : tensor([-0.0510])
# 업데이트 된 W : tensor([-0.0510]), b : tensor([0.1160])
# 수식을 w로 미분한 값 : tensor([-0.0509])
# 업데이트 된 W : tensor([-0.0509]), b : tensor([0.1157])
# 수식을 w로 미분한 값 : tensor([-0.0508])
# 업데이트 된 W : tensor([-0.0508]), b : tensor([0.1155])
# 수식을 w로 미분한 값 : tensor([-0.0507])
# 업데이트 된 W : tensor([-0.0507]), b : tensor([0.1152])
# 수식을 w로 미분한 값 : tensor([-0.0505])
# 업데이트 된 W : tensor([-0.0505]), b : tensor([0.1149])
# 수식을 w로 미분한 값 : tensor([-0.0504])
# 업데이트 된 W : tensor([-0.0504]), b : tensor([0.1146])
# 수식을 w로 미분한 값 : tensor([-0.0503])
# 업데이트 된 W : tensor([-0.0503]), b : tensor([0.1144])
# 수식을 w로 미분한 값 : tensor([-0.0502])
# 업데이트 된 W : tensor([-0.0502]), b : tensor([0.1141])
# 수식을 w로 미분한 값 : tensor([-0.0501])
# 업데이트 된 W : tensor([-0.0501]), b : tensor([0.1138])
# 수식을 w로 미분한 값 : tensor([-0.0499])
# 업데이트 된 W : tensor([-0.0499]), b : tensor([0.1135])
# 수식을 w로 미분한 값 : tensor([-0.0498])
# 업데이트 된 W : tensor([-0.0498]), b : tensor([0.1133])
# 수식을 w로 미분한 값 : tensor([-0.0497])
# 업데이트 된 W : tensor([-0.0497]), b : tensor([0.1130])
# 수식을 w로 미분한 값 : tensor([-0.0496])
# 업데이트 된 W : tensor([-0.0496]), b : tensor([0.1127])
# 수식을 w로 미분한 값 : tensor([-0.0495])
# 업데이트 된 W : tensor([-0.0495]), b : tensor([0.1124])
# 수식을 w로 미분한 값 : tensor([-0.0493])
# 업데이트 된 W : tensor([-0.0493]), b : tensor([0.1122])
# 수식을 w로 미분한 값 : tensor([-0.0492])
# 업데이트 된 W : tensor([-0.0492]), b : tensor([0.1119])
# 수식을 w로 미분한 값 : tensor([-0.0491])
# 업데이트 된 W : tensor([-0.0491]), b : tensor([0.1116])
# 수식을 w로 미분한 값 : tensor([-0.0490])
# 업데이트 된 W : tensor([-0.0490]), b : tensor([0.1114])
# 수식을 w로 미분한 값 : tensor([-0.0489])
# 업데이트 된 W : tensor([-0.0489]), b : tensor([0.1111])
# 수식을 w로 미분한 값 : tensor([-0.0488])
# 업데이트 된 W : tensor([-0.0488]), b : tensor([0.1108])
# 수식을 w로 미분한 값 : tensor([-0.0486])
# 업데이트 된 W : tensor([-0.0486]), b : tensor([0.1106])
# 수식을 w로 미분한 값 : tensor([-0.0485])
# 업데이트 된 W : tensor([-0.0485]), b : tensor([0.1103])
# 수식을 w로 미분한 값 : tensor([-0.0484])
# 업데이트 된 W : tensor([-0.0484]), b : tensor([0.1100])
# 수식을 w로 미분한 값 : tensor([-0.0483])
# 업데이트 된 W : tensor([-0.0483]), b : tensor([0.1098])
# 수식을 w로 미분한 값 : tensor([-0.0482])
# 업데이트 된 W : tensor([-0.0482]), b : tensor([0.1095])
# Epoch  200/1999 W: 1.800, b: 0.454 Cost: 0.029767
# 수식을 w로 미분한 값 : tensor([-0.0481])
# 업데이트 된 W : tensor([-0.0481]), b : tensor([0.1092])
# 수식을 w로 미분한 값 : tensor([-0.0479])
# 업데이트 된 W : tensor([-0.0479]), b : tensor([0.1090])
# 수식을 w로 미분한 값 : tensor([-0.0478])
# 업데이트 된 W : tensor([-0.0478]), b : tensor([0.1087])
# 수식을 w로 미분한 값 : tensor([-0.0477])
# 업데이트 된 W : tensor([-0.0477]), b : tensor([0.1085])
# 수식을 w로 미분한 값 : tensor([-0.0476])
# 업데이트 된 W : tensor([-0.0476]), b : tensor([0.1082])
# 수식을 w로 미분한 값 : tensor([-0.0475])
# 업데이트 된 W : tensor([-0.0475]), b : tensor([0.1079])
# 수식을 w로 미분한 값 : tensor([-0.0474])
# 업데이트 된 W : tensor([-0.0474]), b : tensor([0.1077])
# 수식을 w로 미분한 값 : tensor([-0.0473])
# 업데이트 된 W : tensor([-0.0473]), b : tensor([0.1074])
# 수식을 w로 미분한 값 : tensor([-0.0471])
# 업데이트 된 W : tensor([-0.0471]), b : tensor([0.1072])
# 수식을 w로 미분한 값 : tensor([-0.0470])
# 업데이트 된 W : tensor([-0.0470]), b : tensor([0.1069])
# 수식을 w로 미분한 값 : tensor([-0.0469])
# 업데이트 된 W : tensor([-0.0469]), b : tensor([0.1066])
# 수식을 w로 미분한 값 : tensor([-0.0468])
# 업데이트 된 W : tensor([-0.0468]), b : tensor([0.1064])
# 수식을 w로 미분한 값 : tensor([-0.0467])
# 업데이트 된 W : tensor([-0.0467]), b : tensor([0.1061])
# 수식을 w로 미분한 값 : tensor([-0.0466])
# 업데이트 된 W : tensor([-0.0466]), b : tensor([0.1059])
# 수식을 w로 미분한 값 : tensor([-0.0465])
# 업데이트 된 W : tensor([-0.0465]), b : tensor([0.1056])
# 수식을 w로 미분한 값 : tensor([-0.0464])
# 업데이트 된 W : tensor([-0.0464]), b : tensor([0.1054])
# 수식을 w로 미분한 값 : tensor([-0.0462])
# 업데이트 된 W : tensor([-0.0462]), b : tensor([0.1051])
# 수식을 w로 미분한 값 : tensor([-0.0461])
# 업데이트 된 W : tensor([-0.0461]), b : tensor([0.1049])
# 수식을 w로 미분한 값 : tensor([-0.0460])
# 업데이트 된 W : tensor([-0.0460]), b : tensor([0.1046])
# 수식을 w로 미분한 값 : tensor([-0.0459])
# 업데이트 된 W : tensor([-0.0459]), b : tensor([0.1044])
# 수식을 w로 미분한 값 : tensor([-0.0458])
# 업데이트 된 W : tensor([-0.0458]), b : tensor([0.1041])
# 수식을 w로 미분한 값 : tensor([-0.0457])
# 업데이트 된 W : tensor([-0.0457]), b : tensor([0.1039])
# 수식을 w로 미분한 값 : tensor([-0.0456])
# 업데이트 된 W : tensor([-0.0456]), b : tensor([0.1036])
# 수식을 w로 미분한 값 : tensor([-0.0455])
# 업데이트 된 W : tensor([-0.0455]), b : tensor([0.1034])
# 수식을 w로 미분한 값 : tensor([-0.0454])
# 업데이트 된 W : tensor([-0.0454]), b : tensor([0.1031])
# 수식을 w로 미분한 값 : tensor([-0.0452])
# 업데이트 된 W : tensor([-0.0452]), b : tensor([0.1029])
# 수식을 w로 미분한 값 : tensor([-0.0451])
# 업데이트 된 W : tensor([-0.0451]), b : tensor([0.1026])
# 수식을 w로 미분한 값 : tensor([-0.0450])
# 업데이트 된 W : tensor([-0.0450]), b : tensor([0.1024])
# 수식을 w로 미분한 값 : tensor([-0.0449])
# 업데이트 된 W : tensor([-0.0449]), b : tensor([0.1021])
# 수식을 w로 미분한 값 : tensor([-0.0448])
# 업데이트 된 W : tensor([-0.0448]), b : tensor([0.1019])
# 수식을 w로 미분한 값 : tensor([-0.0447])
# 업데이트 된 W : tensor([-0.0447]), b : tensor([0.1016])
# 수식을 w로 미분한 값 : tensor([-0.0446])
# 업데이트 된 W : tensor([-0.0446]), b : tensor([0.1014])
# 수식을 w로 미분한 값 : tensor([-0.0445])
# 업데이트 된 W : tensor([-0.0445]), b : tensor([0.1011])
# 수식을 w로 미분한 값 : tensor([-0.0444])
# 업데이트 된 W : tensor([-0.0444]), b : tensor([0.1009])
# 수식을 w로 미분한 값 : tensor([-0.0443])
# 업데이트 된 W : tensor([-0.0443]), b : tensor([0.1007])
# 수식을 w로 미분한 값 : tensor([-0.0442])
# 업데이트 된 W : tensor([-0.0442]), b : tensor([0.1004])
# 수식을 w로 미분한 값 : tensor([-0.0441])
# 업데이트 된 W : tensor([-0.0441]), b : tensor([0.1002])
# 수식을 w로 미분한 값 : tensor([-0.0440])
# 업데이트 된 W : tensor([-0.0440]), b : tensor([0.0999])
# 수식을 w로 미분한 값 : tensor([-0.0439])
# 업데이트 된 W : tensor([-0.0439]), b : tensor([0.0997])
# 수식을 w로 미분한 값 : tensor([-0.0437])
# 업데이트 된 W : tensor([-0.0437]), b : tensor([0.0995])
# 수식을 w로 미분한 값 : tensor([-0.0436])
# 업데이트 된 W : tensor([-0.0436]), b : tensor([0.0992])
# 수식을 w로 미분한 값 : tensor([-0.0435])
# 업데이트 된 W : tensor([-0.0435]), b : tensor([0.0990])
# 수식을 w로 미분한 값 : tensor([-0.0434])
# 업데이트 된 W : tensor([-0.0434]), b : tensor([0.0987])
# 수식을 w로 미분한 값 : tensor([-0.0433])
# 업데이트 된 W : tensor([-0.0433]), b : tensor([0.0985])
# 수식을 w로 미분한 값 : tensor([-0.0432])
# 업데이트 된 W : tensor([-0.0432]), b : tensor([0.0983])
# 수식을 w로 미분한 값 : tensor([-0.0431])
# 업데이트 된 W : tensor([-0.0431]), b : tensor([0.0980])
# 수식을 w로 미분한 값 : tensor([-0.0430])
# 업데이트 된 W : tensor([-0.0430]), b : tensor([0.0978])
# 수식을 w로 미분한 값 : tensor([-0.0429])
# 업데이트 된 W : tensor([-0.0429]), b : tensor([0.0976])
# 수식을 w로 미분한 값 : tensor([-0.0428])
# 업데이트 된 W : tensor([-0.0428]), b : tensor([0.0973])
# 수식을 w로 미분한 값 : tensor([-0.0427])
# 업데이트 된 W : tensor([-0.0427]), b : tensor([0.0971])
# 수식을 w로 미분한 값 : tensor([-0.0426])
# 업데이트 된 W : tensor([-0.0426]), b : tensor([0.0969])
# 수식을 w로 미분한 값 : tensor([-0.0425])
# 업데이트 된 W : tensor([-0.0425]), b : tensor([0.0966])
# 수식을 w로 미분한 값 : tensor([-0.0424])
# 업데이트 된 W : tensor([-0.0424]), b : tensor([0.0964])
# 수식을 w로 미분한 값 : tensor([-0.0423])
# 업데이트 된 W : tensor([-0.0423]), b : tensor([0.0962])
# 수식을 w로 미분한 값 : tensor([-0.0422])
# 업데이트 된 W : tensor([-0.0422]), b : tensor([0.0959])
# 수식을 w로 미분한 값 : tensor([-0.0421])
# 업데이트 된 W : tensor([-0.0421]), b : tensor([0.0957])
# 수식을 w로 미분한 값 : tensor([-0.0420])
# 업데이트 된 W : tensor([-0.0420]), b : tensor([0.0955])
# 수식을 w로 미분한 값 : tensor([-0.0419])
# 업데이트 된 W : tensor([-0.0419]), b : tensor([0.0952])
# 수식을 w로 미분한 값 : tensor([-0.0418])
# 업데이트 된 W : tensor([-0.0418]), b : tensor([0.0950])
# 수식을 w로 미분한 값 : tensor([-0.0417])
# 업데이트 된 W : tensor([-0.0417]), b : tensor([0.0948])
# 수식을 w로 미분한 값 : tensor([-0.0416])
# 업데이트 된 W : tensor([-0.0416]), b : tensor([0.0946])
# 수식을 w로 미분한 값 : tensor([-0.0415])
# 업데이트 된 W : tensor([-0.0415]), b : tensor([0.0943])
# 수식을 w로 미분한 값 : tensor([-0.0414])
# 업데이트 된 W : tensor([-0.0414]), b : tensor([0.0941])
# 수식을 w로 미분한 값 : tensor([-0.0413])
# 업데이트 된 W : tensor([-0.0413]), b : tensor([0.0939])
# 수식을 w로 미분한 값 : tensor([-0.0412])
# 업데이트 된 W : tensor([-0.0412]), b : tensor([0.0936])
# 수식을 w로 미분한 값 : tensor([-0.0411])
# 업데이트 된 W : tensor([-0.0411]), b : tensor([0.0934])
# 수식을 w로 미분한 값 : tensor([-0.0410])
# 업데이트 된 W : tensor([-0.0410]), b : tensor([0.0932])
# 수식을 w로 미분한 값 : tensor([-0.0409])
# 업데이트 된 W : tensor([-0.0409]), b : tensor([0.0930])
# 수식을 w로 미분한 값 : tensor([-0.0408])
# 업데이트 된 W : tensor([-0.0408]), b : tensor([0.0927])
# 수식을 w로 미분한 값 : tensor([-0.0407])
# 업데이트 된 W : tensor([-0.0407]), b : tensor([0.0925])
# 수식을 w로 미분한 값 : tensor([-0.0406])
# 업데이트 된 W : tensor([-0.0406]), b : tensor([0.0923])
# 수식을 w로 미분한 값 : tensor([-0.0405])
# 업데이트 된 W : tensor([-0.0405]), b : tensor([0.0921])
# 수식을 w로 미분한 값 : tensor([-0.0404])
# 업데이트 된 W : tensor([-0.0404]), b : tensor([0.0919])
# 수식을 w로 미분한 값 : tensor([-0.0403])
# 업데이트 된 W : tensor([-0.0403]), b : tensor([0.0916])
# 수식을 w로 미분한 값 : tensor([-0.0402])
# 업데이트 된 W : tensor([-0.0402]), b : tensor([0.0914])
# 수식을 w로 미분한 값 : tensor([-0.0401])
# 업데이트 된 W : tensor([-0.0401]), b : tensor([0.0912])
# 수식을 w로 미분한 값 : tensor([-0.0400])
# 업데이트 된 W : tensor([-0.0400]), b : tensor([0.0910])
# 수식을 w로 미분한 값 : tensor([-0.0399])
# 업데이트 된 W : tensor([-0.0399]), b : tensor([0.0908])
# 수식을 w로 미분한 값 : tensor([-0.0398])
# 업데이트 된 W : tensor([-0.0398]), b : tensor([0.0905])
# 수식을 w로 미분한 값 : tensor([-0.0397])
# 업데이트 된 W : tensor([-0.0397]), b : tensor([0.0903])
# 수식을 w로 미분한 값 : tensor([-0.0396])
# 업데이트 된 W : tensor([-0.0396]), b : tensor([0.0901])
# 수식을 w로 미분한 값 : tensor([-0.0395])
# 업데이트 된 W : tensor([-0.0395]), b : tensor([0.0899])
# 수식을 w로 미분한 값 : tensor([-0.0394])
# 업데이트 된 W : tensor([-0.0394]), b : tensor([0.0897])
# 수식을 w로 미분한 값 : tensor([-0.0394])
# 업데이트 된 W : tensor([-0.0394]), b : tensor([0.0895])
# 수식을 w로 미분한 값 : tensor([-0.0393])
# 업데이트 된 W : tensor([-0.0393]), b : tensor([0.0892])
# 수식을 w로 미분한 값 : tensor([-0.0392])
# 업데이트 된 W : tensor([-0.0392]), b : tensor([0.0890])
# 수식을 w로 미분한 값 : tensor([-0.0391])
# 업데이트 된 W : tensor([-0.0391]), b : tensor([0.0888])
# 수식을 w로 미분한 값 : tensor([-0.0390])
# 업데이트 된 W : tensor([-0.0390]), b : tensor([0.0886])
# 수식을 w로 미분한 값 : tensor([-0.0389])
# 업데이트 된 W : tensor([-0.0389]), b : tensor([0.0884])
# 수식을 w로 미분한 값 : tensor([-0.0388])
# 업데이트 된 W : tensor([-0.0388]), b : tensor([0.0882])
# 수식을 w로 미분한 값 : tensor([-0.0387])
# 업데이트 된 W : tensor([-0.0387]), b : tensor([0.0880])
# 수식을 w로 미분한 값 : tensor([-0.0386])
# 업데이트 된 W : tensor([-0.0386]), b : tensor([0.0878])
# 수식을 w로 미분한 값 : tensor([-0.0385])
# 업데이트 된 W : tensor([-0.0385]), b : tensor([0.0875])
# 수식을 w로 미분한 값 : tensor([-0.0384])
# 업데이트 된 W : tensor([-0.0384]), b : tensor([0.0873])
# 수식을 w로 미분한 값 : tensor([-0.0383])
# 업데이트 된 W : tensor([-0.0383]), b : tensor([0.0871])
# 수식을 w로 미분한 값 : tensor([-0.0382])
# 업데이트 된 W : tensor([-0.0382]), b : tensor([0.0869])
# 수식을 w로 미분한 값 : tensor([-0.0381])
# 업데이트 된 W : tensor([-0.0381]), b : tensor([0.0867])
# 수식을 w로 미분한 값 : tensor([-0.0380])
# 업데이트 된 W : tensor([-0.0380]), b : tensor([0.0865])
# 수식을 w로 미분한 값 : tensor([-0.0380])
# 업데이트 된 W : tensor([-0.0380]), b : tensor([0.0863])
# 수식을 w로 미분한 값 : tensor([-0.0379])
# 업데이트 된 W : tensor([-0.0379]), b : tensor([0.0861])
# Epoch  300/1999 W: 1.843, b: 0.357 Cost: 0.018394
# 수식을 w로 미분한 값 : tensor([-0.0378])
# 업데이트 된 W : tensor([-0.0378]), b : tensor([0.0859])
# 수식을 w로 미분한 값 : tensor([-0.0377])
# 업데이트 된 W : tensor([-0.0377]), b : tensor([0.0857])
# 수식을 w로 미분한 값 : tensor([-0.0376])
# 업데이트 된 W : tensor([-0.0376]), b : tensor([0.0855])
# 수식을 w로 미분한 값 : tensor([-0.0375])
# 업데이트 된 W : tensor([-0.0375]), b : tensor([0.0853])
# 수식을 w로 미분한 값 : tensor([-0.0374])
# 업데이트 된 W : tensor([-0.0374]), b : tensor([0.0850])
# 수식을 w로 미분한 값 : tensor([-0.0373])
# 업데이트 된 W : tensor([-0.0373]), b : tensor([0.0848])
# 수식을 w로 미분한 값 : tensor([-0.0372])
# 업데이트 된 W : tensor([-0.0372]), b : tensor([0.0846])
# 수식을 w로 미분한 값 : tensor([-0.0371])
# 업데이트 된 W : tensor([-0.0371]), b : tensor([0.0844])
# 수식을 w로 미분한 값 : tensor([-0.0371])
# 업데이트 된 W : tensor([-0.0371]), b : tensor([0.0842])
# 수식을 w로 미분한 값 : tensor([-0.0370])
# 업데이트 된 W : tensor([-0.0370]), b : tensor([0.0840])
# 수식을 w로 미분한 값 : tensor([-0.0369])
# 업데이트 된 W : tensor([-0.0369]), b : tensor([0.0838])
# 수식을 w로 미분한 값 : tensor([-0.0368])
# 업데이트 된 W : tensor([-0.0368]), b : tensor([0.0836])
# 수식을 w로 미분한 값 : tensor([-0.0367])
# 업데이트 된 W : tensor([-0.0367]), b : tensor([0.0834])
# 수식을 w로 미분한 값 : tensor([-0.0366])
# 업데이트 된 W : tensor([-0.0366]), b : tensor([0.0832])
# 수식을 w로 미분한 값 : tensor([-0.0365])
# 업데이트 된 W : tensor([-0.0365]), b : tensor([0.0830])
# 수식을 w로 미분한 값 : tensor([-0.0364])
# 업데이트 된 W : tensor([-0.0364]), b : tensor([0.0828])
# 수식을 w로 미분한 값 : tensor([-0.0363])
# 업데이트 된 W : tensor([-0.0363]), b : tensor([0.0826])
# 수식을 w로 미분한 값 : tensor([-0.0363])
# 업데이트 된 W : tensor([-0.0363]), b : tensor([0.0824])
# 수식을 w로 미분한 값 : tensor([-0.0362])
# 업데이트 된 W : tensor([-0.0362]), b : tensor([0.0822])
# 수식을 w로 미분한 값 : tensor([-0.0361])
# 업데이트 된 W : tensor([-0.0361]), b : tensor([0.0820])
# 수식을 w로 미분한 값 : tensor([-0.0360])
# 업데이트 된 W : tensor([-0.0360]), b : tensor([0.0818])
# 수식을 w로 미분한 값 : tensor([-0.0359])
# 업데이트 된 W : tensor([-0.0359]), b : tensor([0.0816])
# 수식을 w로 미분한 값 : tensor([-0.0358])
# 업데이트 된 W : tensor([-0.0358]), b : tensor([0.0814])
# 수식을 w로 미분한 값 : tensor([-0.0357])
# 업데이트 된 W : tensor([-0.0357]), b : tensor([0.0812])
# 수식을 w로 미분한 값 : tensor([-0.0357])
# 업데이트 된 W : tensor([-0.0357]), b : tensor([0.0811])
# 수식을 w로 미분한 값 : tensor([-0.0356])
# 업데이트 된 W : tensor([-0.0356]), b : tensor([0.0809])
# 수식을 w로 미분한 값 : tensor([-0.0355])
# 업데이트 된 W : tensor([-0.0355]), b : tensor([0.0807])
# 수식을 w로 미분한 값 : tensor([-0.0354])
# 업데이트 된 W : tensor([-0.0354]), b : tensor([0.0805])
# 수식을 w로 미분한 값 : tensor([-0.0353])
# 업데이트 된 W : tensor([-0.0353]), b : tensor([0.0803])
# 수식을 w로 미분한 값 : tensor([-0.0352])
# 업데이트 된 W : tensor([-0.0352]), b : tensor([0.0801])
# 수식을 w로 미분한 값 : tensor([-0.0351])
# 업데이트 된 W : tensor([-0.0351]), b : tensor([0.0799])
# 수식을 w로 미분한 값 : tensor([-0.0351])
# 업데이트 된 W : tensor([-0.0351]), b : tensor([0.0797])
# 수식을 w로 미분한 값 : tensor([-0.0350])
# 업데이트 된 W : tensor([-0.0350]), b : tensor([0.0795])
# 수식을 w로 미분한 값 : tensor([-0.0349])
# 업데이트 된 W : tensor([-0.0349]), b : tensor([0.0793])
# 수식을 w로 미분한 값 : tensor([-0.0348])
# 업데이트 된 W : tensor([-0.0348]), b : tensor([0.0791])
# 수식을 w로 미분한 값 : tensor([-0.0347])
# 업데이트 된 W : tensor([-0.0347]), b : tensor([0.0789])
# 수식을 w로 미분한 값 : tensor([-0.0346])
# 업데이트 된 W : tensor([-0.0346]), b : tensor([0.0787])
# 수식을 w로 미분한 값 : tensor([-0.0346])
# 업데이트 된 W : tensor([-0.0346]), b : tensor([0.0786])
# 수식을 w로 미분한 값 : tensor([-0.0345])
# 업데이트 된 W : tensor([-0.0345]), b : tensor([0.0784])
# 수식을 w로 미분한 값 : tensor([-0.0344])
# 업데이트 된 W : tensor([-0.0344]), b : tensor([0.0782])
# 수식을 w로 미분한 값 : tensor([-0.0343])
# 업데이트 된 W : tensor([-0.0343]), b : tensor([0.0780])
# 수식을 w로 미분한 값 : tensor([-0.0342])
# 업데이트 된 W : tensor([-0.0342]), b : tensor([0.0778])
# 수식을 w로 미분한 값 : tensor([-0.0341])
# 업데이트 된 W : tensor([-0.0341]), b : tensor([0.0776])
# 수식을 w로 미분한 값 : tensor([-0.0341])
# 업데이트 된 W : tensor([-0.0341]), b : tensor([0.0774])
# 수식을 w로 미분한 값 : tensor([-0.0340])
# 업데이트 된 W : tensor([-0.0340]), b : tensor([0.0772])
# 수식을 w로 미분한 값 : tensor([-0.0339])
# 업데이트 된 W : tensor([-0.0339]), b : tensor([0.0771])
# 수식을 w로 미분한 값 : tensor([-0.0338])
# 업데이트 된 W : tensor([-0.0338]), b : tensor([0.0769])
# 수식을 w로 미분한 값 : tensor([-0.0337])
# 업데이트 된 W : tensor([-0.0337]), b : tensor([0.0767])
# 수식을 w로 미분한 값 : tensor([-0.0337])
# 업데이트 된 W : tensor([-0.0337]), b : tensor([0.0765])
# 수식을 w로 미분한 값 : tensor([-0.0336])
# 업데이트 된 W : tensor([-0.0336]), b : tensor([0.0763])
# 수식을 w로 미분한 값 : tensor([-0.0335])
# 업데이트 된 W : tensor([-0.0335]), b : tensor([0.0761])
# 수식을 w로 미분한 값 : tensor([-0.0334])
# 업데이트 된 W : tensor([-0.0334]), b : tensor([0.0760])
# 수식을 w로 미분한 값 : tensor([-0.0333])
# 업데이트 된 W : tensor([-0.0333]), b : tensor([0.0758])
# 수식을 w로 미분한 값 : tensor([-0.0333])
# 업데이트 된 W : tensor([-0.0333]), b : tensor([0.0756])
# 수식을 w로 미분한 값 : tensor([-0.0332])
# 업데이트 된 W : tensor([-0.0332]), b : tensor([0.0754])
# 수식을 w로 미분한 값 : tensor([-0.0331])
# 업데이트 된 W : tensor([-0.0331]), b : tensor([0.0752])
# 수식을 w로 미분한 값 : tensor([-0.0330])
# 업데이트 된 W : tensor([-0.0330]), b : tensor([0.0750])
# 수식을 w로 미분한 값 : tensor([-0.0329])
# 업데이트 된 W : tensor([-0.0329]), b : tensor([0.0749])
# 수식을 w로 미분한 값 : tensor([-0.0329])
# 업데이트 된 W : tensor([-0.0329]), b : tensor([0.0747])
# 수식을 w로 미분한 값 : tensor([-0.0328])
# 업데이트 된 W : tensor([-0.0328]), b : tensor([0.0745])
# 수식을 w로 미분한 값 : tensor([-0.0327])
# 업데이트 된 W : tensor([-0.0327]), b : tensor([0.0743])
# 수식을 w로 미분한 값 : tensor([-0.0326])
# 업데이트 된 W : tensor([-0.0326]), b : tensor([0.0741])
# 수식을 w로 미분한 값 : tensor([-0.0325])
# 업데이트 된 W : tensor([-0.0325]), b : tensor([0.0740])
# 수식을 w로 미분한 값 : tensor([-0.0325])
# 업데이트 된 W : tensor([-0.0325]), b : tensor([0.0738])
# 수식을 w로 미분한 값 : tensor([-0.0324])
# 업데이트 된 W : tensor([-0.0324]), b : tensor([0.0736])
# 수식을 w로 미분한 값 : tensor([-0.0323])
# 업데이트 된 W : tensor([-0.0323]), b : tensor([0.0734])
# 수식을 w로 미분한 값 : tensor([-0.0322])
# 업데이트 된 W : tensor([-0.0322]), b : tensor([0.0733])
# 수식을 w로 미분한 값 : tensor([-0.0321])
# 업데이트 된 W : tensor([-0.0321]), b : tensor([0.0731])
# 수식을 w로 미분한 값 : tensor([-0.0321])
# 업데이트 된 W : tensor([-0.0321]), b : tensor([0.0729])
# 수식을 w로 미분한 값 : tensor([-0.0320])
# 업데이트 된 W : tensor([-0.0320]), b : tensor([0.0727])
# 수식을 w로 미분한 값 : tensor([-0.0319])
# 업데이트 된 W : tensor([-0.0319]), b : tensor([0.0726])
# 수식을 w로 미분한 값 : tensor([-0.0318])
# 업데이트 된 W : tensor([-0.0318]), b : tensor([0.0724])
# 수식을 w로 미분한 값 : tensor([-0.0318])
# 업데이트 된 W : tensor([-0.0318]), b : tensor([0.0722])
# 수식을 w로 미분한 값 : tensor([-0.0317])
# 업데이트 된 W : tensor([-0.0317]), b : tensor([0.0720])
# 수식을 w로 미분한 값 : tensor([-0.0316])
# 업데이트 된 W : tensor([-0.0316]), b : tensor([0.0719])
# 수식을 w로 미분한 값 : tensor([-0.0315])
# 업데이트 된 W : tensor([-0.0315]), b : tensor([0.0717])
# 수식을 w로 미분한 값 : tensor([-0.0315])
# 업데이트 된 W : tensor([-0.0315]), b : tensor([0.0715])
# 수식을 w로 미분한 값 : tensor([-0.0314])
# 업데이트 된 W : tensor([-0.0314]), b : tensor([0.0713])
# 수식을 w로 미분한 값 : tensor([-0.0313])
# 업데이트 된 W : tensor([-0.0313]), b : tensor([0.0712])
# 수식을 w로 미분한 값 : tensor([-0.0312])
# 업데이트 된 W : tensor([-0.0312]), b : tensor([0.0710])
# 수식을 w로 미분한 값 : tensor([-0.0312])
# 업데이트 된 W : tensor([-0.0312]), b : tensor([0.0708])
# 수식을 w로 미분한 값 : tensor([-0.0311])
# 업데이트 된 W : tensor([-0.0311]), b : tensor([0.0707])
# 수식을 w로 미분한 값 : tensor([-0.0310])
# 업데이트 된 W : tensor([-0.0310]), b : tensor([0.0705])
# 수식을 w로 미분한 값 : tensor([-0.0309])
# 업데이트 된 W : tensor([-0.0309]), b : tensor([0.0703])
# 수식을 w로 미분한 값 : tensor([-0.0309])
# 업데이트 된 W : tensor([-0.0309]), b : tensor([0.0702])
# 수식을 w로 미분한 값 : tensor([-0.0308])
# 업데이트 된 W : tensor([-0.0308]), b : tensor([0.0700])
# 수식을 w로 미분한 값 : tensor([-0.0307])
# 업데이트 된 W : tensor([-0.0307]), b : tensor([0.0698])
# 수식을 w로 미분한 값 : tensor([-0.0306])
# 업데이트 된 W : tensor([-0.0306]), b : tensor([0.0696])
# 수식을 w로 미분한 값 : tensor([-0.0306])
# 업데이트 된 W : tensor([-0.0306]), b : tensor([0.0695])
# 수식을 w로 미분한 값 : tensor([-0.0305])
# 업데이트 된 W : tensor([-0.0305]), b : tensor([0.0693])
# 수식을 w로 미분한 값 : tensor([-0.0304])
# 업데이트 된 W : tensor([-0.0304]), b : tensor([0.0691])
# 수식을 w로 미분한 값 : tensor([-0.0303])
# 업데이트 된 W : tensor([-0.0303]), b : tensor([0.0690])
# 수식을 w로 미분한 값 : tensor([-0.0303])
# 업데이트 된 W : tensor([-0.0303]), b : tensor([0.0688])
# 수식을 w로 미분한 값 : tensor([-0.0302])
# 업데이트 된 W : tensor([-0.0302]), b : tensor([0.0687])
# 수식을 w로 미분한 값 : tensor([-0.0301])
# 업데이트 된 W : tensor([-0.0301]), b : tensor([0.0685])
# 수식을 w로 미분한 값 : tensor([-0.0301])
# 업데이트 된 W : tensor([-0.0301]), b : tensor([0.0683])
# 수식을 w로 미분한 값 : tensor([-0.0300])
# 업데이트 된 W : tensor([-0.0300]), b : tensor([0.0682])
# 수식을 w로 미분한 값 : tensor([-0.0299])
# 업데이트 된 W : tensor([-0.0299]), b : tensor([0.0680])
# 수식을 w로 미분한 값 : tensor([-0.0298])
# 업데이트 된 W : tensor([-0.0298]), b : tensor([0.0678])
# 수식을 w로 미분한 값 : tensor([-0.0298])
# 업데이트 된 W : tensor([-0.0298]), b : tensor([0.0677])
# Epoch  400/1999 W: 1.876, b: 0.281 Cost: 0.011366
# 수식을 w로 미분한 값 : tensor([-0.0297])
# 업데이트 된 W : tensor([-0.0297]), b : tensor([0.0675])
# 수식을 w로 미분한 값 : tensor([-0.0296])
# 업데이트 된 W : tensor([-0.0296]), b : tensor([0.0673])
# 수식을 w로 미분한 값 : tensor([-0.0296])
# 업데이트 된 W : tensor([-0.0296]), b : tensor([0.0672])
# 수식을 w로 미분한 값 : tensor([-0.0295])
# 업데이트 된 W : tensor([-0.0295]), b : tensor([0.0670])
# 수식을 w로 미분한 값 : tensor([-0.0294])
# 업데이트 된 W : tensor([-0.0294]), b : tensor([0.0669])
# 수식을 w로 미분한 값 : tensor([-0.0293])
# 업데이트 된 W : tensor([-0.0293]), b : tensor([0.0667])
# 수식을 w로 미분한 값 : tensor([-0.0293])
# 업데이트 된 W : tensor([-0.0293]), b : tensor([0.0665])
# 수식을 w로 미분한 값 : tensor([-0.0292])
# 업데이트 된 W : tensor([-0.0292]), b : tensor([0.0664])
# 수식을 w로 미분한 값 : tensor([-0.0291])
# 업데이트 된 W : tensor([-0.0291]), b : tensor([0.0662])
# 수식을 w로 미분한 값 : tensor([-0.0291])
# 업데이트 된 W : tensor([-0.0291]), b : tensor([0.0661])
# 수식을 w로 미분한 값 : tensor([-0.0290])
# 업데이트 된 W : tensor([-0.0290]), b : tensor([0.0659])
# 수식을 w로 미분한 값 : tensor([-0.0289])
# 업데이트 된 W : tensor([-0.0289]), b : tensor([0.0657])
# 수식을 w로 미분한 값 : tensor([-0.0288])
# 업데이트 된 W : tensor([-0.0288]), b : tensor([0.0656])
# 수식을 w로 미분한 값 : tensor([-0.0288])
# 업데이트 된 W : tensor([-0.0288]), b : tensor([0.0654])
# 수식을 w로 미분한 값 : tensor([-0.0287])
# 업데이트 된 W : tensor([-0.0287]), b : tensor([0.0653])
# 수식을 w로 미분한 값 : tensor([-0.0286])
# 업데이트 된 W : tensor([-0.0286]), b : tensor([0.0651])
# 수식을 w로 미분한 값 : tensor([-0.0286])
# 업데이트 된 W : tensor([-0.0286]), b : tensor([0.0650])
# 수식을 w로 미분한 값 : tensor([-0.0285])
# 업데이트 된 W : tensor([-0.0285]), b : tensor([0.0648])
# 수식을 w로 미분한 값 : tensor([-0.0284])
# 업데이트 된 W : tensor([-0.0284]), b : tensor([0.0646])
# 수식을 w로 미분한 값 : tensor([-0.0284])
# 업데이트 된 W : tensor([-0.0284]), b : tensor([0.0645])
# 수식을 w로 미분한 값 : tensor([-0.0283])
# 업데이트 된 W : tensor([-0.0283]), b : tensor([0.0643])
# 수식을 w로 미분한 값 : tensor([-0.0282])
# 업데이트 된 W : tensor([-0.0282]), b : tensor([0.0642])
# 수식을 w로 미분한 값 : tensor([-0.0282])
# 업데이트 된 W : tensor([-0.0282]), b : tensor([0.0640])
# 수식을 w로 미분한 값 : tensor([-0.0281])
# 업데이트 된 W : tensor([-0.0281]), b : tensor([0.0639])
# 수식을 w로 미분한 값 : tensor([-0.0280])
# 업데이트 된 W : tensor([-0.0280]), b : tensor([0.0637])
# 수식을 w로 미분한 값 : tensor([-0.0280])
# 업데이트 된 W : tensor([-0.0280]), b : tensor([0.0636])
# 수식을 w로 미분한 값 : tensor([-0.0279])
# 업데이트 된 W : tensor([-0.0279]), b : tensor([0.0634])
# 수식을 w로 미분한 값 : tensor([-0.0278])
# 업데이트 된 W : tensor([-0.0278]), b : tensor([0.0633])
# 수식을 w로 미분한 값 : tensor([-0.0278])
# 업데이트 된 W : tensor([-0.0278]), b : tensor([0.0631])
# 수식을 w로 미분한 값 : tensor([-0.0277])
# 업데이트 된 W : tensor([-0.0277]), b : tensor([0.0630])
# 수식을 w로 미분한 값 : tensor([-0.0276])
# 업데이트 된 W : tensor([-0.0276]), b : tensor([0.0628])
# 수식을 w로 미분한 값 : tensor([-0.0276])
# 업데이트 된 W : tensor([-0.0276]), b : tensor([0.0627])
# 수식을 w로 미분한 값 : tensor([-0.0275])
# 업데이트 된 W : tensor([-0.0275]), b : tensor([0.0625])
# 수식을 w로 미분한 값 : tensor([-0.0274])
# 업데이트 된 W : tensor([-0.0274]), b : tensor([0.0623])
# 수식을 w로 미분한 값 : tensor([-0.0274])
# 업데이트 된 W : tensor([-0.0274]), b : tensor([0.0622])
# 수식을 w로 미분한 값 : tensor([-0.0273])
# 업데이트 된 W : tensor([-0.0273]), b : tensor([0.0621])
# 수식을 w로 미분한 값 : tensor([-0.0272])
# 업데이트 된 W : tensor([-0.0272]), b : tensor([0.0619])
# 수식을 w로 미분한 값 : tensor([-0.0272])
# 업데이트 된 W : tensor([-0.0272]), b : tensor([0.0618])
# 수식을 w로 미분한 값 : tensor([-0.0271])
# 업데이트 된 W : tensor([-0.0271]), b : tensor([0.0616])
# 수식을 w로 미분한 값 : tensor([-0.0270])
# 업데이트 된 W : tensor([-0.0270]), b : tensor([0.0615])
# 수식을 w로 미분한 값 : tensor([-0.0270])
# 업데이트 된 W : tensor([-0.0270]), b : tensor([0.0613])
# 수식을 w로 미분한 값 : tensor([-0.0269])
# 업데이트 된 W : tensor([-0.0269]), b : tensor([0.0612])
# 수식을 w로 미분한 값 : tensor([-0.0268])
# 업데이트 된 W : tensor([-0.0268]), b : tensor([0.0610])
# 수식을 w로 미분한 값 : tensor([-0.0268])
# 업데이트 된 W : tensor([-0.0268]), b : tensor([0.0609])
# 수식을 w로 미분한 값 : tensor([-0.0267])
# 업데이트 된 W : tensor([-0.0267]), b : tensor([0.0607])
# 수식을 w로 미분한 값 : tensor([-0.0266])
# 업데이트 된 W : tensor([-0.0266]), b : tensor([0.0606])
# 수식을 w로 미분한 값 : tensor([-0.0266])
# 업데이트 된 W : tensor([-0.0266]), b : tensor([0.0604])
# 수식을 w로 미분한 값 : tensor([-0.0265])
# 업데이트 된 W : tensor([-0.0265]), b : tensor([0.0603])
# 수식을 w로 미분한 값 : tensor([-0.0265])
# 업데이트 된 W : tensor([-0.0265]), b : tensor([0.0601])
# 수식을 w로 미분한 값 : tensor([-0.0264])
# 업데이트 된 W : tensor([-0.0264]), b : tensor([0.0600])
# 수식을 w로 미분한 값 : tensor([-0.0263])
# 업데이트 된 W : tensor([-0.0263]), b : tensor([0.0599])
# 수식을 w로 미분한 값 : tensor([-0.0263])
# 업데이트 된 W : tensor([-0.0263]), b : tensor([0.0597])
# 수식을 w로 미분한 값 : tensor([-0.0262])
# 업데이트 된 W : tensor([-0.0262]), b : tensor([0.0596])
# 수식을 w로 미분한 값 : tensor([-0.0261])
# 업데이트 된 W : tensor([-0.0261]), b : tensor([0.0594])
# 수식을 w로 미분한 값 : tensor([-0.0261])
# 업데이트 된 W : tensor([-0.0261]), b : tensor([0.0593])
# 수식을 w로 미분한 값 : tensor([-0.0260])
# 업데이트 된 W : tensor([-0.0260]), b : tensor([0.0591])
# 수식을 w로 미분한 값 : tensor([-0.0259])
# 업데이트 된 W : tensor([-0.0259]), b : tensor([0.0590])
# 수식을 w로 미분한 값 : tensor([-0.0259])
# 업데이트 된 W : tensor([-0.0259]), b : tensor([0.0589])
# 수식을 w로 미분한 값 : tensor([-0.0258])
# 업데이트 된 W : tensor([-0.0258]), b : tensor([0.0587])
# 수식을 w로 미분한 값 : tensor([-0.0258])
# 업데이트 된 W : tensor([-0.0258]), b : tensor([0.0586])
# 수식을 w로 미분한 값 : tensor([-0.0257])
# 업데이트 된 W : tensor([-0.0257]), b : tensor([0.0584])
# 수식을 w로 미분한 값 : tensor([-0.0256])
# 업데이트 된 W : tensor([-0.0256]), b : tensor([0.0583])
# 수식을 w로 미분한 값 : tensor([-0.0256])
# 업데이트 된 W : tensor([-0.0256]), b : tensor([0.0581])
# 수식을 w로 미분한 값 : tensor([-0.0255])
# 업데이트 된 W : tensor([-0.0255]), b : tensor([0.0580])
# 수식을 w로 미분한 값 : tensor([-0.0255])
# 업데이트 된 W : tensor([-0.0255]), b : tensor([0.0579])
# 수식을 w로 미분한 값 : tensor([-0.0254])
# 업데이트 된 W : tensor([-0.0254]), b : tensor([0.0577])
# 수식을 w로 미분한 값 : tensor([-0.0253])
# 업데이트 된 W : tensor([-0.0253]), b : tensor([0.0576])
# 수식을 w로 미분한 값 : tensor([-0.0253])
# 업데이트 된 W : tensor([-0.0253]), b : tensor([0.0575])
# 수식을 w로 미분한 값 : tensor([-0.0252])
# 업데이트 된 W : tensor([-0.0252]), b : tensor([0.0573])
# 수식을 w로 미분한 값 : tensor([-0.0252])
# 업데이트 된 W : tensor([-0.0252]), b : tensor([0.0572])
# 수식을 w로 미분한 값 : tensor([-0.0251])
# 업데이트 된 W : tensor([-0.0251]), b : tensor([0.0570])
# 수식을 w로 미분한 값 : tensor([-0.0250])
# 업데이트 된 W : tensor([-0.0250]), b : tensor([0.0569])
# 수식을 w로 미분한 값 : tensor([-0.0250])
# 업데이트 된 W : tensor([-0.0250]), b : tensor([0.0568])
# 수식을 w로 미분한 값 : tensor([-0.0249])
# 업데이트 된 W : tensor([-0.0249]), b : tensor([0.0566])
# 수식을 w로 미분한 값 : tensor([-0.0248])
# 업데이트 된 W : tensor([-0.0248]), b : tensor([0.0565])
# 수식을 w로 미분한 값 : tensor([-0.0248])
# 업데이트 된 W : tensor([-0.0248]), b : tensor([0.0564])
# 수식을 w로 미분한 값 : tensor([-0.0247])
# 업데이트 된 W : tensor([-0.0247]), b : tensor([0.0562])
# 수식을 w로 미분한 값 : tensor([-0.0247])
# 업데이트 된 W : tensor([-0.0247]), b : tensor([0.0561])
# 수식을 w로 미분한 값 : tensor([-0.0246])
# 업데이트 된 W : tensor([-0.0246]), b : tensor([0.0560])
# 수식을 w로 미분한 값 : tensor([-0.0246])
# 업데이트 된 W : tensor([-0.0246]), b : tensor([0.0558])
# 수식을 w로 미분한 값 : tensor([-0.0245])
# 업데이트 된 W : tensor([-0.0245]), b : tensor([0.0557])
# 수식을 w로 미분한 값 : tensor([-0.0244])
# 업데이트 된 W : tensor([-0.0244]), b : tensor([0.0555])
# 수식을 w로 미분한 값 : tensor([-0.0244])
# 업데이트 된 W : tensor([-0.0244]), b : tensor([0.0554])
# 수식을 w로 미분한 값 : tensor([-0.0243])
# 업데이트 된 W : tensor([-0.0243]), b : tensor([0.0553])
# 수식을 w로 미분한 값 : tensor([-0.0243])
# 업데이트 된 W : tensor([-0.0243]), b : tensor([0.0551])
# 수식을 w로 미분한 값 : tensor([-0.0242])
# 업데이트 된 W : tensor([-0.0242]), b : tensor([0.0550])
# 수식을 w로 미분한 값 : tensor([-0.0241])
# 업데이트 된 W : tensor([-0.0241]), b : tensor([0.0549])
# 수식을 w로 미분한 값 : tensor([-0.0241])
# 업데이트 된 W : tensor([-0.0241]), b : tensor([0.0548])
# 수식을 w로 미분한 값 : tensor([-0.0240])
# 업데이트 된 W : tensor([-0.0240]), b : tensor([0.0546])
# 수식을 w로 미분한 값 : tensor([-0.0240])
# 업데이트 된 W : tensor([-0.0240]), b : tensor([0.0545])
# 수식을 w로 미분한 값 : tensor([-0.0239])
# 업데이트 된 W : tensor([-0.0239]), b : tensor([0.0544])
# 수식을 w로 미분한 값 : tensor([-0.0239])
# 업데이트 된 W : tensor([-0.0239]), b : tensor([0.0542])
# 수식을 w로 미분한 값 : tensor([-0.0238])
# 업데이트 된 W : tensor([-0.0238]), b : tensor([0.0541])
# 수식을 w로 미분한 값 : tensor([-0.0237])
# 업데이트 된 W : tensor([-0.0237]), b : tensor([0.0540])
# 수식을 w로 미분한 값 : tensor([-0.0237])
# 업데이트 된 W : tensor([-0.0237]), b : tensor([0.0538])
# 수식을 w로 미분한 값 : tensor([-0.0236])
# 업데이트 된 W : tensor([-0.0236]), b : tensor([0.0537])
# 수식을 w로 미분한 값 : tensor([-0.0236])
# 업데이트 된 W : tensor([-0.0236]), b : tensor([0.0536])
# 수식을 w로 미분한 값 : tensor([-0.0235])
# 업데이트 된 W : tensor([-0.0235]), b : tensor([0.0534])
# 수식을 w로 미분한 값 : tensor([-0.0235])
# 업데이트 된 W : tensor([-0.0235]), b : tensor([0.0533])
# 수식을 w로 미분한 값 : tensor([-0.0234])
# 업데이트 된 W : tensor([-0.0234]), b : tensor([0.0532])
# Epoch  500/1999 W: 1.903, b: 0.221 Cost: 0.007024
# 수식을 w로 미분한 값 : tensor([-0.0233])
# 업데이트 된 W : tensor([-0.0233]), b : tensor([0.0531])
# 수식을 w로 미분한 값 : tensor([-0.0233])
# 업데이트 된 W : tensor([-0.0233]), b : tensor([0.0529])
# 수식을 w로 미분한 값 : tensor([-0.0232])
# 업데이트 된 W : tensor([-0.0232]), b : tensor([0.0528])
# 수식을 w로 미분한 값 : tensor([-0.0232])
# 업데이트 된 W : tensor([-0.0232]), b : tensor([0.0527])
# 수식을 w로 미분한 값 : tensor([-0.0231])
# 업데이트 된 W : tensor([-0.0231]), b : tensor([0.0526])
# 수식을 w로 미분한 값 : tensor([-0.0231])
# 업데이트 된 W : tensor([-0.0231]), b : tensor([0.0524])
# 수식을 w로 미분한 값 : tensor([-0.0230])
# 업데이트 된 W : tensor([-0.0230]), b : tensor([0.0523])
# 수식을 w로 미분한 값 : tensor([-0.0230])
# 업데이트 된 W : tensor([-0.0230]), b : tensor([0.0522])
# 수식을 w로 미분한 값 : tensor([-0.0229])
# 업데이트 된 W : tensor([-0.0229]), b : tensor([0.0521])
# 수식을 w로 미분한 값 : tensor([-0.0228])
# 업데이트 된 W : tensor([-0.0228]), b : tensor([0.0519])
# 수식을 w로 미분한 값 : tensor([-0.0228])
# 업데이트 된 W : tensor([-0.0228]), b : tensor([0.0518])
# 수식을 w로 미분한 값 : tensor([-0.0227])
# 업데이트 된 W : tensor([-0.0227]), b : tensor([0.0517])
# 수식을 w로 미분한 값 : tensor([-0.0227])
# 업데이트 된 W : tensor([-0.0227]), b : tensor([0.0516])
# 수식을 w로 미분한 값 : tensor([-0.0226])
# 업데이트 된 W : tensor([-0.0226]), b : tensor([0.0514])
# 수식을 w로 미분한 값 : tensor([-0.0226])
# 업데이트 된 W : tensor([-0.0226]), b : tensor([0.0513])
# 수식을 w로 미분한 값 : tensor([-0.0225])
# 업데이트 된 W : tensor([-0.0225]), b : tensor([0.0512])
# 수식을 w로 미분한 값 : tensor([-0.0225])
# 업데이트 된 W : tensor([-0.0225]), b : tensor([0.0511])
# 수식을 w로 미분한 값 : tensor([-0.0224])
# 업데이트 된 W : tensor([-0.0224]), b : tensor([0.0509])
# 수식을 w로 미분한 값 : tensor([-0.0224])
# 업데이트 된 W : tensor([-0.0224]), b : tensor([0.0508])
# 수식을 w로 미분한 값 : tensor([-0.0223])
# 업데이트 된 W : tensor([-0.0223]), b : tensor([0.0507])
# 수식을 w로 미분한 값 : tensor([-0.0222])
# 업데이트 된 W : tensor([-0.0222]), b : tensor([0.0506])
# 수식을 w로 미분한 값 : tensor([-0.0222])
# 업데이트 된 W : tensor([-0.0222]), b : tensor([0.0504])
# 수식을 w로 미분한 값 : tensor([-0.0221])
# 업데이트 된 W : tensor([-0.0221]), b : tensor([0.0503])
# 수식을 w로 미분한 값 : tensor([-0.0221])
# 업데이트 된 W : tensor([-0.0221]), b : tensor([0.0502])
# 수식을 w로 미분한 값 : tensor([-0.0220])
# 업데이트 된 W : tensor([-0.0220]), b : tensor([0.0501])
# 수식을 w로 미분한 값 : tensor([-0.0220])
# 업데이트 된 W : tensor([-0.0220]), b : tensor([0.0500])
# 수식을 w로 미분한 값 : tensor([-0.0219])
# 업데이트 된 W : tensor([-0.0219]), b : tensor([0.0498])
# 수식을 w로 미분한 값 : tensor([-0.0219])
# 업데이트 된 W : tensor([-0.0219]), b : tensor([0.0497])
# 수식을 w로 미분한 값 : tensor([-0.0218])
# 업데이트 된 W : tensor([-0.0218]), b : tensor([0.0496])
# 수식을 w로 미분한 값 : tensor([-0.0218])
# 업데이트 된 W : tensor([-0.0218]), b : tensor([0.0495])
# 수식을 w로 미분한 값 : tensor([-0.0217])
# 업데이트 된 W : tensor([-0.0217]), b : tensor([0.0494])
# 수식을 w로 미분한 값 : tensor([-0.0217])
# 업데이트 된 W : tensor([-0.0217]), b : tensor([0.0492])
# 수식을 w로 미분한 값 : tensor([-0.0216])
# 업데이트 된 W : tensor([-0.0216]), b : tensor([0.0491])
# 수식을 w로 미분한 값 : tensor([-0.0216])
# 업데이트 된 W : tensor([-0.0216]), b : tensor([0.0490])
# 수식을 w로 미분한 값 : tensor([-0.0215])
# 업데이트 된 W : tensor([-0.0215]), b : tensor([0.0489])
# 수식을 w로 미분한 값 : tensor([-0.0215])
# 업데이트 된 W : tensor([-0.0215]), b : tensor([0.0488])
# 수식을 w로 미분한 값 : tensor([-0.0214])
# 업데이트 된 W : tensor([-0.0214]), b : tensor([0.0487])
# 수식을 w로 미분한 값 : tensor([-0.0214])
# 업데이트 된 W : tensor([-0.0214]), b : tensor([0.0485])
# 수식을 w로 미분한 값 : tensor([-0.0213])
# 업데이트 된 W : tensor([-0.0213]), b : tensor([0.0484])
# 수식을 w로 미분한 값 : tensor([-0.0213])
# 업데이트 된 W : tensor([-0.0213]), b : tensor([0.0483])
# 수식을 w로 미분한 값 : tensor([-0.0212])
# 업데이트 된 W : tensor([-0.0212]), b : tensor([0.0482])
# 수식을 w로 미분한 값 : tensor([-0.0211])
# 업데이트 된 W : tensor([-0.0211]), b : tensor([0.0481])
# 수식을 w로 미분한 값 : tensor([-0.0211])
# 업데이트 된 W : tensor([-0.0211]), b : tensor([0.0480])
# 수식을 w로 미분한 값 : tensor([-0.0210])
# 업데이트 된 W : tensor([-0.0210]), b : tensor([0.0478])
# 수식을 w로 미분한 값 : tensor([-0.0210])
# 업데이트 된 W : tensor([-0.0210]), b : tensor([0.0477])
# 수식을 w로 미분한 값 : tensor([-0.0209])
# 업데이트 된 W : tensor([-0.0209]), b : tensor([0.0476])
# 수식을 w로 미분한 값 : tensor([-0.0209])
# 업데이트 된 W : tensor([-0.0209]), b : tensor([0.0475])
# 수식을 w로 미분한 값 : tensor([-0.0208])
# 업데이트 된 W : tensor([-0.0208]), b : tensor([0.0474])
# 수식을 w로 미분한 값 : tensor([-0.0208])
# 업데이트 된 W : tensor([-0.0208]), b : tensor([0.0473])
# 수식을 w로 미분한 값 : tensor([-0.0207])
# 업데이트 된 W : tensor([-0.0207]), b : tensor([0.0472])
# 수식을 w로 미분한 값 : tensor([-0.0207])
# 업데이트 된 W : tensor([-0.0207]), b : tensor([0.0470])
# 수식을 w로 미분한 값 : tensor([-0.0206])
# 업데이트 된 W : tensor([-0.0206]), b : tensor([0.0469])
# 수식을 w로 미분한 값 : tensor([-0.0206])
# 업데이트 된 W : tensor([-0.0206]), b : tensor([0.0468])
# 수식을 w로 미분한 값 : tensor([-0.0205])
# 업데이트 된 W : tensor([-0.0205]), b : tensor([0.0467])
# 수식을 w로 미분한 값 : tensor([-0.0205])
# 업데이트 된 W : tensor([-0.0205]), b : tensor([0.0466])
# 수식을 w로 미분한 값 : tensor([-0.0204])
# 업데이트 된 W : tensor([-0.0204]), b : tensor([0.0465])
# 수식을 w로 미분한 값 : tensor([-0.0204])
# 업데이트 된 W : tensor([-0.0204]), b : tensor([0.0464])
# 수식을 w로 미분한 값 : tensor([-0.0204])
# 업데이트 된 W : tensor([-0.0204]), b : tensor([0.0463])
# 수식을 w로 미분한 값 : tensor([-0.0203])
# 업데이트 된 W : tensor([-0.0203]), b : tensor([0.0461])
# 수식을 w로 미분한 값 : tensor([-0.0203])
# 업데이트 된 W : tensor([-0.0203]), b : tensor([0.0460])
# 수식을 w로 미분한 값 : tensor([-0.0202])
# 업데이트 된 W : tensor([-0.0202]), b : tensor([0.0459])
# 수식을 w로 미분한 값 : tensor([-0.0202])
# 업데이트 된 W : tensor([-0.0202]), b : tensor([0.0458])
# 수식을 w로 미분한 값 : tensor([-0.0201])
# 업데이트 된 W : tensor([-0.0201]), b : tensor([0.0457])
# 수식을 w로 미분한 값 : tensor([-0.0201])
# 업데이트 된 W : tensor([-0.0201]), b : tensor([0.0456])
# 수식을 w로 미분한 값 : tensor([-0.0200])
# 업데이트 된 W : tensor([-0.0200]), b : tensor([0.0455])
# 수식을 w로 미분한 값 : tensor([-0.0200])
# 업데이트 된 W : tensor([-0.0200]), b : tensor([0.0454])
# ...
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0023])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0023])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0023])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0023])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0023])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0010])
# 업데이트 된 W : tensor([-0.0010]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0022])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0021])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0020])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0009])
# 업데이트 된 W : tensor([-0.0009]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0019])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# Epoch 1900/1999 W: 1.997, b: 0.008 Cost: 0.000008
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0018])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0008])
# 업데이트 된 W : tensor([-0.0008]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0017])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0016])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0007])
# 업데이트 된 W : tensor([-0.0007]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0015])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0014])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0014])
# 수식을 w로 미분한 값 : tensor([-0.0006])
# 업데이트 된 W : tensor([-0.0006]), b : tensor([0.0014])

# %%
## 학습 완료 후의 W, b  텐서 값 확인
W.item(), b.item()
# Out:
# (1.9999783039093018, 4.8881796828936785e-05)

# %%
## x값 넣고 y값 확인
pre_y = W*3+b
pre_y.item()
# Out:
# 5.999984264373779

# %%
num=12
avg=3.45567

f'num = {num}, {num:*^10}, avg = {avg} {avg:10.3f}'
# Out:
# 'num = 12, ****12****, avg = 3.45567      3.456'

# %%
## optimizer.zero_grad()가 필요한 이유
## 미분을 통해 얻은 기울기를 이전에 계산된 기울기 값에 누적시키는 특징

w = torch.tensor(2.0, requires_grad=True)

nb_epochs = 20
for epoch in range(nb_epochs + 1):

  z = 2*w

  z.backward()
  print('수식을 w로 미분한 값 : {}'.format(w.grad))
# Out:
# 수식을 w로 미분한 값 : 2.0
# 수식을 w로 미분한 값 : 4.0
# 수식을 w로 미분한 값 : 6.0
# 수식을 w로 미분한 값 : 8.0
# 수식을 w로 미분한 값 : 10.0
# 수식을 w로 미분한 값 : 12.0
# 수식을 w로 미분한 값 : 14.0
# 수식을 w로 미분한 값 : 16.0
# 수식을 w로 미분한 값 : 18.0
# 수식을 w로 미분한 값 : 20.0
# 수식을 w로 미분한 값 : 22.0
# 수식을 w로 미분한 값 : 24.0
# 수식을 w로 미분한 값 : 26.0
# 수식을 w로 미분한 값 : 28.0
# 수식을 w로 미분한 값 : 30.0
# 수식을 w로 미분한 값 : 32.0
# 수식을 w로 미분한 값 : 34.0
# 수식을 w로 미분한 값 : 36.0
# 수식을 w로 미분한 값 : 38.0
# 수식을 w로 미분한 값 : 40.0
# 수식을 w로 미분한 값 : 42.0
